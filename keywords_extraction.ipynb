# %%
from keybert import KeyBERT
from kiwipiepy import Kiwi
from transformers import BertModel
import pandas as pd
from collections import defaultdict
import glob
import math
from tqdm import tqdm
import numpy as np

# %%
model = BertModel.from_pretrained('skt/kobert-base-v1')
kw_model = KeyBERT(model)
# keywords = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words=None, top_n=10)
# keywords

# %%
kiwi = Kiwi()

# %%
# 명사 추출 함수
def noun_extractor(text):
    results = []
    result = kiwi.analyze(text)
    for token, pos, _, _ in result[0][0]:
        if len(token) != 1 and pos.startswith('N') or pos.startswith('SL'):
            results.append(token)
    return results

# %%
review_files = glob.glob('./DF/*csv')
review_files
# Out:
# ['./DF\\AIGames.DSFMK.csv',
#  './DF\\cjenm.ModooMarbleKakao.csv',
#  './DF\\cjenm.monster.csv',
#  './DF\\cjenm.sknights.csv',
#  './DF\\Danalgames.CobFighter.csv',
#  './DF\\dddgame.sd3.csv',
#  './DF\\fincon.hh.csv',
#  './DF\\fincon.hh2.csv',
#  './DF\\fingertips.kof98umol.csv',
#  './DF\\flerogames.ES.csv',
#  './DF\\ftt.hero_gl_4kakao.csv',
#  './DF\\funnypack.rfkakao.csv',
#  './DF\\gamevil.psrforkakao.csv',
#  './DF\\grampus.cookingadventureforkakao.csv',
#  './DF\\joymax.candypang2.csv',
#  './DF\\joymax.gostop.csv',
#  './DF\\kakaogames.archewar.csv',
#  './DF\\kakaogames.ares.csv',
#  './DF\\kakaogames.eversoul.csv',
#  './DF\\kakaogames.friendsKing.csv',
#  './DF\\kakaogames.friendsScpuzzle.csv',
#  './DF\\kakaogames.friendsTower.csv',
#  './DF\\kakaogames.friendsTown.csv',
#  './DF\\kakaogames.gdtskr.csv',
#  './DF\\kakaogames.grdchase.csv',
#  './DF\\kakaogames.hellobt21.csv',
#  './DF\\kakaogames.lmzgplay.csv',
#  './DF\\kakaogames.moonlight.csv',
#  './DF\\kakaogames.myhome.csv',
#  './DF\\kakaogames.nikki.csv',
#  './DF\\kakaogames.odin.csv',
#  './DF\\kakaogames.pcr.csv',
#  './DF\\kakaogames.umamusume.csv',
#  './DF\\kakaogames.wdfp.csv',
#  './DF\\linekong.sszj.krgp.csv',
#  './DF\\longtukorea.snmg.csv',
#  './DF\\longtukorea.yulgang.csv',
#  './DF\\lunosoft.disneyhiddencatch.csv',
#  './DF\\lunosoft.hmg.csv',
#  './DF\\mobilfactory.mylittlefarm.csv',
#  './DF\\monomob.baduk2.csv',
#  './DF\\monomob.jangki.csv',
#  './DF\\monomob.omok.csv',
#  './DF\\neowiz.games.newmatgoKakao.csv',
#  './DF\\neowiz.games.pokerKakao.csv',
#  './DF\\neowiz.games.suddaKakao.csv',
#  './DF\\neptune.tantan.csv',
#  './DF\\nexon.baram.csv',
#  './DF\\nexon.hit2.csv',
#  './DF\\nexon.kart.csv',
#  './DF\\nexon.nsc.maplem.csv',
#  './DF\\nexon.v4kr.csv',
#  './DF\\ngonsub.VikingIsland.csv',
#  './DF\\nhnent.SKPOKOPOKO.csv',
#  './DF\\nhnpixelcube.friendspop.csv',
#  './DF\\noknok.BEAUTYCITY.csv',
#  './DF\\noknok.HappyDelivery.csv',
#  './DF\\noknok.heroesinnkakao.csv',
#  './DF\\noknok.HHBREAD.csv',
#  './DF\\noknok.mart.csv',
#  './DF\\noknok.small.csv',
#  './DF\\npixel.GranSaga.csv',
#  './DF\\o.feverstudio.apps.everytown.csv',
#  './DF\\o.sonew.chickentycoon3.google.csv',
#  './DF\\o.sonew.ilh.kakao.csv',
#  './DF\\oknok.FashionCity.csv',
#  './DF\\oknok.HappyLifeKr.csv',
#  './DF\\patigames.ilovepasta4kakao.csv',
#  './DF\\patistudio.milc4kakao.csv',
#  './DF\\proximabeta.tdm.kr.csv',
#  './DF\\purplekiwii.mbkakao.csv',
#  './DF\\sandwichgames.puzzlethreego.csv',
#  './DF\\softzen.stycoon.csv',
#  './DF\\sundaytoz.kakao.anipang3.service.csv',
#  './DF\\sundaytoz.kakao.anipang4.csv',
#  './DF\\sundaytoz.kakao.anipangtouch.csv',
#  './DF\\sundaytoz.kakao.diffgame.csv',
#  './DF\\sundaytoz.kakao.joy.csv',
#  './DF\\sundaytoz.kakao.matgo.service.csv',
#  './DF\\sundaytoz.kakao.poker.service.csv',
#  './DF\\sundaytoz.kakao.shanghai.service.csv',
#  './DF\\sundaytoz.kakao.sutda.service.csv',
#  './DF\\sundaytoz.kakao.wbb.csv',
#  './DF\\sundaytoz.mobile.anipang.google.service.csv',
#  './DF\\sundaytoz.mobile.anipang2.google.kakao.service.csv',
#  './DF\\sundaytoz.mobile.anisachun.google.service.csv',
#  './DF\\SuperAwesome.HKFKakao.csv',
#  './DF\\webzen.mua2.google.csv',
#  './DF\\wemade.mir4.csv',
#  './DF\\wemade.mirm.csv',
#  './DF\\zenimax.bladeskakaonew.csv']

# %%
li = []
stop_words = ["게임", "이거", "하나", "유저", "나름", "업데이트", "접속", "플레이"]
for path in tqdm(review_files):
    d = defaultdict(int)
    df = pd.read_csv(path)
    for review in df['reviews']:
        if type(review) == str:
            nouns = noun_extractor(review)
            text = ' '.join(nouns)
            keywords = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words=stop_words, top_n=20)
            for key, val in keywords:
                d[key] += val
        elif math.isnan(review):
            continue
    # li.append(sorted(d.items(), key= lambda x: -x[1])[:10])
    li.append(sorted(d.items(), key= lambda x: -x[1])) # 전체를 다 주는경우
# Out:
# 100%|██████████| 91/91 [39:54<00:00, 26.32s/it]

# %%
li
# Out:
# [[('재미', 20.0958),
#   ('선수', 13.8591),
#   ('시간', 12.5131),
#   ('나름', 7.0),
#   ('처음', 6.1943),
#   ('재밋', 5.7599),
#   ('축구', 4.2936),
#   ('재밋어요', 3.9778000000000002),
#   ('그래픽', 3.1656),
#   ('플레이', 3.1583),
#   ('최고', 3.1231),
#   ('킬링타임', 3.0),
#   ('감독', 2.8066),
#   ('업뎃', 2.7363),
#   ('시작', 2.7119),
#   ('생각', 2.7088),
#   ('적응', 2.4588),
#   ('진행', 2.4396),
#   ('터치', 2.3418),
#   ('fm', 2.3023),
#   ('자동', 2.1298),
#   ('과금', 2.1244),
#   ('조아요', 2.0),
#   ('good', 1.9992),
#   ('만족', 1.9937),
#   ('재밋네', 1.9868000000000001),
#   ('리얼', 1.9042),
#   ('화면', 1.8942999999999999),
#   ('잼나요', 1.8809),
#   ('조작', 1.8357),
#   ('킬링', 1.7932000000000001),
#   ('단순', 1.7351999999999999),
#   ('정도', 1.6633),
#   ('초반', 1.6472),
#   ('매니저', 1.6205),
#   ('느낌', 1.5967),
#   ('심심풀이', 1.5857999999999999),
#   ('부분', 1.5790000000000002),
#   ('필요', 1.5756000000000001),
#   ('전술', 1.4945),
#   ('예전', 1.4926),
#   ('이름', 1.4901),
#   ('오랜만', 1.4047),
#   ('기능', 1.3860000000000001),
#   ('영입', 1.3814),
#   ('경기', 1.3517000000000001),
#   ('업데이트', 1.3138),
#   ('최근', 1.2991000000000001),
#   ('뽑기', 1.2921),
#   ('관리', 1.2212),
#   ('부탁', 1.1459000000000001),
#   ('모바일', 1.0881),
#   ('위치', 1.0551),
#   ('레벨', 1.029),
#   ('스쿼드', 1.0191),
#   ('전반', 1.0),
#   ('카드', 1.0),
#   ('시스템', 1.0),
#   ('영상', 1.0),
#   ('손흥민', 1.0),
#   ('캐릭', 1.0),
#   ('무엇', 1.0),
#   ('무과', 1.0),
#   ('차구차구', 1.0),
#   ('신경', 1.0),
#   ('특별', 1.0),
#   ('설치', 1.0),
#   ('루즈', 1.0),
#   ('너무재밋네요', 1.0),
#   ('재밋는거가트요', 1.0),
#   ('단계', 1.0),
#   ('스토리', 1.0),
#   ('잼잏게', 1.0),
#   ('설레네유', 1.0),
#   ('재밍', 1.0),
#   ('단조', 1.0),
#   ('생각보다재밓', 1.0),
#   ('제미', 1.0),
#   ('수고', 1.0),
#   ('괞츦음', 1.0),
#   ('잡이', 1.0),
#   ('재미아', 1.0),
#   ('이적', 1.0),
#   ('쏘쏘', 1.0),
#   ('그럭저레', 1.0),
#   ('재밋네여', 1.0),
#   ('재밋다쉽고', 1.0),
#   ('요햐햐산', 1.0),
#   ('고고', 1.0),
#   ('굳굳굳', 1.0),
#   ('빼에에에에에에에에', 1.0),
#   ('에펨느낌굳', 1.0),
#   ('재밋네요', 1.0),
#   ('재밋게', 1.0),
#   ('화이팅', 1.0),
#   ('조아브러', 1.0),
#   ('럭저럭', 1.0),
#   ('잼네', 1.0),
#   ('존재', 1.0),
#   ('낙나', 1.0),
#   ('개꿀잼', 1.0),
#   ('굿짝퉁스', 1.0),
#   ('재밋누', 1.0),
#   ('go', 0.9987),
#   ('굿뜨', 0.9852),
#   ('좋아여여여', 0.9848),
#   ('갠찮네요', 0.9838),
#   ('쪼꼬매', 0.9821),
#   ('대로', 0.9769),
#   ('goodddddddd', 0.9728),
#   ('잼나여', 0.9659),
#   ('윽시', 0.9621),
#   ('soso', 0.9594),
#   ('인터페이스', 0.9487),
#   ('잼나', 0.9457),
#   ('이해', 0.9456),
#   ('경험', 0.9389),
#   ('업그레이드', 0.9317),
#   ('여여여', 0.9236),
#   ('독성', 0.9212),
#   ('구틓', 0.9168),
#   ('독촉', 0.9144),
#   ('국산', 0.9093),
#   ('감사', 0.9054),
#   ('잼슴', 0.8979),
#   ('대미', 0.8953),
#   ('지긍은', 0.8921),
#   ('맞쳐가', 0.8917),
#   ('여기', 0.8852),
#   ('현재', 0.878),
#   ('대장', 0.8694),
#   ('옛날', 0.8658),
#   ('당신', 0.8612),
#   ('짜증', 0.858),
#   ('타임', 0.8579),
#   ('보상', 0.8565),
#   ('이상', 0.8534),
#   ('지금', 0.8503),
#   ('카페', 0.8467),
#   ('스피드', 0.8457),
#   ('재밋고', 0.8421),
#   ('방식', 0.8399000000000001),
#   ('추억', 0.8394),
#   ('조금', 0.8381),
#   ('온라인', 0.8358),
#   ('대리', 0.8354),
#   ('심플', 0.8224),
#   ('매니지', 0.8195),
#   ('불편', 0.8102),
#   ('지연', 0.8029),
#   ('풋볼', 0.8),
#   ('여지', 0.7981),
#   ('세부', 0.776),
#   ('선호', 0.7661),
#   ('접근', 0.7591),
#   ('메인', 0.7557),
#   ('시즌', 0.7533),
#   ('주발', 0.7516),
#   ('접속', 0.7484),
#   ('고민', 0.7459),
#   ('그거', 0.744),
#   ('호나우두', 0.7422),
#   ('카피작', 0.7411),
#   ('있슴', 0.737),
#   ('데이', 0.7368),
#   ('어디', 0.7346),
#   ('자체', 0.7327),
#   ('리뷰', 0.7309),
#   ('바보', 0.7224),
#   ('직관', 0.7168),
#   ('표기', 0.7126),
#   ('지능', 0.7061),
#   ('플레이어', 0.7005),
#   ('생존자', 0.6787),
#   ('기록', 0.6758),
#   ('편리', 0.6713),
#   ('광고', 0.6703),
#   ('수정', 0.6659),
#   ('유도', 0.6629),
#   ('사용', 0.6612),
#   ('언제', 0.6583),
#   ('인기', 0.6509),
#   ('마찬가지', 0.6445),
#   ('능력', 0.6416),
#   ('정신', 0.64),
#   ('진입', 0.639),
#   ('인공', 0.6304),
#   ('가입', 0.6192),
#   ('이유', 0.6141),
#   ('모드', 0.6125),
#   ('등급', 0.5893),
#   ('종류', 0.5778),
#   ('지단', 0.5729),
#   ('fc', 0.5721),
#   ('과금유', 0.5683),
#   ('정보', 0.5677),
#   ('클럽', 0.557),
#   ('베컴', 0.552),
#   ('흥미', 0.5327),
#   ('경기장', 0.5322),
#   ('컨디션', 0.5322),
#   ('보고', 0.5159),
#   ('변수', 0.5149),
#   ('비교', 0.5118),
#   ('유니폼', 0.5113),
#   ('정리', 0.5085),
#   ('필수', 0.5071),
#   ('우기', 0.4998),
#   ('실감', 0.4982),
#   ('체력', 0.4976),
#   ('취향', 0.4975),
#   ('위주', 0.4923),
#   ('의미', 0.4837),
#   ('은퇴', 0.4831),
#   ('얼마', 0.4827),
#   ('피파', 0.4802),
#   ('은근', 0.4723),
#   ('가능', 0.4717),
#   ('저작권', 0.4706),
#   ('대부분', 0.4525),
#   ('즐거움', 0.4509),
#   ('버전', 0.4397),
#   ('확인', 0.4292),
#   ('완벽', 0.4216),
#   ('인벤', 0.4007),
#   ('하이라이트', 0.3857),
#   ('배치', 0.3723),
#   ('tp', 0.3279),
#   ('제품', 0.3163),
#   ('선택', 0.3056),
#   ('엠블럼', 0.287),
#   ('제작', 0.2759),
#   ('범위', 0.2635),
#   ('요즘', 0.2587),
#   ('세로', 0.2569),
#   ('가로', 0.2521),
#   ('장기', 0.2521),
#   ('각종', 0.2481),
#   ('소수', 0.2453),
#   ('무과금', 0.2413),
#   ('구매', 0.2412),
#   ('수급', 0.2376),
#   ('유저', 0.2325),
#   ('기대', 0.2258),
#   ('총평', 0.2148),
#   ('때문', 0.2015),
#   ('캐시재화', 0.1778),
#   ('섭종', 0.1552),
#   ('이벤', 0.1398),
#   ('영자', 0.1111)],
#  [('유저', 69.02319999999997),
#   ('아이템', 63.83149999999998),
#   ('캐릭터', 57.9121),
#   ('이벤트', 46.320199999999986),
#   ('확률', 40.24760000000001),
#   ('생각', 37.4374),
#   ('플레이', 37.228300000000004),
#   ('사람', 36.85039999999999),
#   ('카드', 36.3367),
#   ('정도', 36.02460000000001),
#   ('현지', 35.8362),
#   ('모마', 33.74820000000001),
#   ('행템', 32.37109999999999),
#   ('마블', 31.97239999999999),
#   ('업데이트', 31.83030000000001),
#   ('예전', 30.927799999999998),
#   ('주사위', 30.905299999999993),
#   ('다이아', 30.679299999999994),
#   ('상대', 28.0475),
#   ('복귀', 27.378400000000003),
#   ('이상', 27.294400000000003),
#   ('옛날', 26.107499999999995),
#   ('시작', 26.028399999999994),
#   ('능력', 24.8266),
#   ('지금', 24.15280000000001),
#   ('모두', 23.890699999999995),
#   ('오류', 22.966399999999993),
#   ('오랜만', 22.440600000000003),
#   ('재미', 20.5793),
#   ('때문', 19.049100000000003),
#   ('행운', 18.5836),
#   ('친구', 18.505099999999995),
#   ('처음', 18.121399999999998),
#   ('접속', 17.4577),
#   ('삭제', 16.711599999999997),
#   ('밸런스', 16.410399999999996),
#   ('감사', 15.978500000000002),
#   ('문제', 15.871000000000002),
#   ('매칭', 15.755200000000002),
#   ('버그', 14.854300000000002),
#   ('경우', 14.745600000000001),
#   ('안녕하세요', 13.506500000000003),
#   ('요즘', 13.3445),
#   ('유도', 13.090499999999999),
#   ('필요', 12.931699999999998),
#   ('이것', 12.675000000000002),
#   ('시간', 12.297899999999998),
#   ('이제', 12.2104),
#   ('발동', 12.074599999999998),
#   ('패치', 11.9886),
#   ('신규', 11.5669),
#   ('부탁', 11.556600000000001),
#   ('발생', 11.411399999999999),
#   ('이번', 11.354099999999999),
#   ('해결', 11.314799999999998),
#   ('스킬', 11.211799999999998),
#   ('리그', 10.6391),
#   ('상황', 10.5374),
#   ('출시', 10.4155),
#   ('상대방', 10.258600000000001),
#   ('짜증', 10.2033),
#   ('캐릭', 9.881299999999998),
#   ('그거', 9.632000000000001),
#   ('진행', 9.5131),
#   ('수정', 9.505500000000001),
#   ('주작', 9.3589),
#   ('과금', 8.914499999999999),
#   ('신캐', 8.9014),
#   ('가지', 8.879800000000001),
#   ('개선', 8.8766),
#   ('등급', 8.648299999999999),
#   ('보상', 8.559),
#   ('동안', 8.5472),
#   ('뽑기', 8.5106),
#   ('로그인', 8.3652),
#   ('방법', 8.321499999999999),
#   ('최근', 8.011599999999998),
#   ('자체', 8.009099999999998),
#   ('강화', 7.896000000000001),
#   ('상태', 7.7698),
#   ('와이파이', 7.751200000000001),
#   ('연속', 7.6335999999999995),
#   ('조작', 7.6282000000000005),
#   ('업뎃', 7.522199999999999),
#   ('장애', 7.355799999999999),
#   ('이유', 7.1652),
#   ('컨트롤', 7.107700000000001),
#   ('가능', 7.0656),
#   ('그것', 7.0647),
#   ('설치', 7.0245999999999995),
#   ('넷마블', 6.9685999999999995),
#   ('문의', 6.9667),
#   ('랜드마크', 6.772600000000001),
#   ('모드', 6.720600000000001),
#   ('원래', 6.6636),
#   ('일시', 6.635700000000001),
#   ('골드', 6.6198),
#   ('실력', 6.619399999999999),
#   ('인증', 6.606999999999999),
#   ('미션', 6.5803),
#   ('보드게임', 6.5413),
#   ('방어', 6.5251),
#   ('사용', 6.520999999999999),
#   ('화면', 6.513),
#   ('리뷰', 6.4422000000000015),
#   ('차이', 6.4028),
#   ('다음', 6.382499999999999),
#   ('초기', 6.3284),
#   ('기능', 6.2958),
#   ('기존', 6.256399999999999),
#   ('계정', 6.221200000000001),
#   ('답변', 6.146399999999999),
#   ('챔피언', 6.0836),
#   ('추억', 6.054600000000001),
#   ('점수', 5.822099999999999),
#   ('자동', 5.742699999999999),
#   ('어디', 5.6189),
#   ('승부', 5.6076),
#   ('결국', 5.5877),
#   ('개인전', 5.578),
#   ('그때', 5.487),
#   ('각성', 5.4744),
#   ('조금', 5.4072000000000005),
#   ('자기', 5.2788),
#   ('플레이어', 5.1987000000000005),
#   ('보조', 5.1959),
#   ('이동', 5.1261),
#   ('효과', 4.894799999999999),
#   ('사기', 4.876399999999999),
#   ('과정', 4.834300000000001),
#   ('퍼스트', 4.782799999999999),
#   ('표시', 4.768000000000001),
#   ('등등', 4.6411),
#   ('사기캐', 4.555899999999999),
#   ('방식', 4.5497),
#   ('버튼', 4.4691),
#   ('추가', 4.468299999999999),
#   ('운영자', 4.4646),
#   ('진화', 4.4642),
#   ('불편', 4.4594),
#   ('말씀', 4.452),
#   ('전략', 4.3952),
#   ('기본', 4.3619),
#   ('시절', 4.3515),
#   ('현상', 4.338),
#   ('마음', 4.308300000000001),
#   ('행태', 4.3002),
#   ('나름', 4.2918),
#   ('실망', 4.2411),
#   ('이해', 4.2326),
#   ('독점', 4.220000000000001),
#   ('스트레스', 4.1912),
#   ('초창기', 4.175),
#   ('뉴비', 4.1749),
#   ('헬멧', 4.1351),
#   ('계속', 4.1106),
#   ('클래식', 4.0921),
#   ('다운로드', 4.0865),
#   ('진짜', 3.9941000000000004),
#   ('이전', 3.9798999999999998),
#   ('인물', 3.9656000000000002),
#   ('복구', 3.9498000000000006),
#   ('망겜', 3.9444),
#   ('어이', 3.9405),
#   ('다양', 3.9353999999999996),
#   ('제한', 3.9278999999999993),
#   ('하루', 3.8236000000000003),
#   ('데이터', 3.8235000000000006),
#   ('기간', 3.8103000000000002),
#   ('개인', 3.7435000000000005),
#   ('시엘', 3.7117999999999993),
#   ('별사탕', 3.7062),
#   ('성장', 3.6827),
#   ('선택', 3.6662),
#   ('프로', 3.6348000000000003),
#   ('진입', 3.628),
#   ('레벨', 3.6252),
#   ('통행료', 3.6218000000000004),
#   ('코스', 3.6138),
#   ('참여', 3.6071999999999997),
#   ('합성', 3.5765),
#   ('획득', 3.5735),
#   ('주컨', 3.5423),
#   ('리셋', 3.5401),
#   ('랭킹', 3.5292),
#   ('케릭', 3.4985999999999997),
#   ('핸드폰', 3.4831000000000003),
#   ('반복', 3.4659),
#   ('순간이동', 3.4623),
#   ('운영', 3.4207),
#   ('최악', 3.412),
#   ('큐브', 3.4054),
#   ('무과금', 3.3927000000000005),
#   ('사항', 3.3913),
#   ('이후', 3.3903999999999996),
#   ('난이도', 3.3782),
#   ('쓰레기', 3.3765),
#   ('주년', 3.3694000000000006),
#   ('기분', 3.3511),
#   ('요소', 3.2885999999999997),
#   ('장착', 3.2727),
#   ('한판', 3.2539),
#   ('종료', 3.239),
#   ('설명', 3.2304),
#   ('얘기', 3.2173),
#   ('다운', 3.2116),
#   ('일반', 3.1992),
#   ('수준', 3.1662999999999997),
#   ('터치', 3.162),
#   ('건물', 3.1612999999999998),
#   ('설정', 3.1606),
#   ('현질러', 3.1418),
#   ('성능', 3.1237999999999997),
#   ('누구', 3.1149),
#   ('완료', 3.0896000000000003),
#   ('거기', 3.0281000000000002),
#   ('유지', 3.0275),
#   ('라인', 3.0148),
#   ('격차', 2.9702),
#   ('인기', 2.9298),
#   ('여기', 2.9245),
#   ('시스템', 2.9227000000000003),
#   ('언제', 2.9098),
#   ('문제점', 2.8990000000000005),
#   ('수상', 2.8794),
#   ('모두의마블', 2.8377),
#   ('기회', 2.8303),
#   ('세계', 2.8219),
#   ('보유', 2.8127000000000004),
#   ('저번', 2.7977999999999996),
#   ('성공', 2.7921),
#   ('오늘', 2.7902),
#   ('강제', 2.7769),
#   ('패배', 2.7761),
#   ('무료', 2.7729),
#   ('건설', 2.7638),
#   ('내용', 2.7519),
#   ('확인', 2.7514000000000003),
#   ('갓겜', 2.7363),
#   ('조정', 2.7056999999999998),
#   ('고객', 2.6984),
#   ('승률', 2.6838),
#   ('연결', 2.6828999999999996),
#   ('마찬가지', 2.6670000000000003),
#   ('응원', 2.66),
#   ('이득', 2.6528),
#   ('초보', 2.6385),
#   ('초심', 2.6205000000000003),
#   ('템빨', 2.6032),
#   ('파산', 2.5974000000000004),
#   ('조절', 2.5965),
#   ('소리', 2.5937),
#   ('과도', 2.5930999999999997),
#   ('중간', 2.5329),
#   ('친선', 2.5206),
#   ('덕분', 2.5202999999999998),
#   ('카톡', 2.5119),
#   ('도중', 2.5),
#   ('소환', 2.4741),
#   ('베라', 2.4736999999999996),
#   ('운빨', 2.4645),
#   ('조합', 2.4591000000000003),
#   ('년도', 2.4488000000000003),
#   ('벨런스', 2.4439),
#   ('이모티콘', 2.4373),
#   ('ai', 2.432),
#   ('파이터', 2.4305),
#   ('무과', 2.4257),
#   ('더블', 2.42),
#   ('시일', 2.4189000000000003),
#   ('지원', 2.4067),
#   ('실행', 2.4024),
#   ('과금러', 2.3975),
#   ('적용', 2.3903000000000003),
#   ('고정', 2.3896),
#   ('나중', 2.3872),
#   ('도감', 2.3855),
#   ('차례', 2.3763),
#   ('애초', 2.3629000000000002),
#   ('흥미', 2.3587000000000002),
#   ('보석', 2.3478),
#   ('조건', 2.3336),
#   ('서버', 2.3331),
#   ('행탬', 2.3255),
#   ('요새', 2.3182),
#   ('캐슬', 2.301),
#   ('센터', 2.294),
#   ('기대', 2.2906),
#   ('너프', 2.2686),
#   ('재화', 2.2662000000000004),
#   ('아침', 2.2623999999999995),
#   ('자신', 2.252),
#   ('출첵', 2.2445),
#   ('승패', 2.2435),
#   ('별점', 2.2318000000000002),
#   ('튜토리얼', 2.2203),
#   ('초대', 2.1958),
#   ('공간', 2.195),
#   ('다크', 2.1924),
#   ('장비', 2.1804),
#   ('사실', 2.1784),
#   ('노가다', 2.1754),
#   ('개발자', 2.1714),
#   ('블랙홀', 2.168),
#   ('2턴', 2.1545),
#   ('적응', 2.1525),
#   ('부분', 2.1376999999999997),
#   ('실패', 2.1285999999999996),
#   ('입장', 2.1260000000000003),
#   ('장벽', 2.1245),
#   ('최소', 2.1202),
#   ('플래티넘', 2.0976999999999997),
#   ('모습', 2.0894),
#   ('출석', 2.0815),
#   ('고려', 2.0807),
#   ('위치', 2.0794),
#   ('우편함', 2.056),
#   ('사기템', 2.0498000000000003),
#   ('저장', 2.0404),
#   ('변경', 2.0393),
#   ('카카오', 2.0279),
#   ('오랫동안', 2.0261),
#   ('유입', 2.0233000000000003),
#   ('부족', 2.0072),
#   ('프카팩', 1.9771),
#   ('여행', 1.9688999999999999),
#   ('채팅', 1.968),
#   ('퍼센트', 1.9614),
#   ('패키지', 1.9557000000000002),
#   ('전우치', 1.9538000000000002),
#   ('붕괴', 1.9506),
#   ('학생', 1.9324),
#   ('워너원', 1.9244),
#   ('무시', 1.9145000000000003),
#   ('무엇', 1.9095),
#   ('주기', 1.9089),
#   ('지속', 1.9087999999999998),
#   ('제거', 1.9036),
#   ('작성', 1.8974000000000002),
#   ('신고', 1.8944),
#   ('우주맵', 1.8875000000000002),
#   ('노잼', 1.8862999999999999),
#   ('무과금러', 1.8843999999999999),
#   ('장난', 1.8754),
#   ('도시', 1.8697),
#   ('옵션', 1.8568),
#   ('가격', 1.8563000000000003),
#   ('그동안', 1.8443),
#   ('그지', 1.8358000000000003),
#   ('평소', 1.834),
#   ('평점', 1.8336),
#   ('결론', 1.8222999999999998),
#   ('부루', 1.8109000000000002),
#   ('당황', 1.8091),
#   ('상위', 1.8082),
#   ('다크루시드', 1.8064),
#   ('장점', 1.7909999999999997),
#   ('와중', 1.7909000000000002),
#   ('출발지', 1.7908),
#   ('선전', 1.7854999999999999),
#   ('의견', 1.7853),
#   ('대전', 1.7837),
#   ('캐릭빨', 1.7767),
#   ('도착', 1.7728),
#   ('여러분', 1.7610999999999999),
#   ('상점', 1.7561),
#   ('향수', 1.756),
#   ('마지막', 1.753),
#   ('전체', 1.7512),
#   ('수고', 1.7482),
#   ('이름', 1.7436),
#   ('피드백', 1.7389),
#   ('현실', 1.7298),
#   ('연승', 1.7253),
#   ('제보', 1.7250999999999999),
#   ('댓글', 1.7198),
#   ('저희', 1.7155),
#   ('결과', 1.7144),
#   ('재밋', 1.7102),
#   ('캐릭이', 1.7039999999999997),
#   ('한국', 1.7033),
#   ('승리', 1.6944000000000001),
#   ('교환', 1.6938),
#   ('벨런스가', 1.6803),
#   ('닉네임', 1.6768999999999998),
#   ('승급', 1.6702000000000001),
#   ('한계', 1.6622000000000001),
#   ('중복', 1.6532),
#   ('랜덤', 1.6280999999999999),
#   ('향상', 1.6269),
#   ('고속', 1.6249),
#   ('따위', 1.6237),
#   ('컨텐츠', 1.6215),
#   ('배려', 1.6187999999999998),
#   ('단점', 1.6179000000000001),
#   ('결정', 1.6174000000000002),
#   ('대기', 1.6097000000000001),
#   ('밸붕', 1.6021),
#   ('기억', 1.5997),
#   ('막장', 1.5924),
#   ('얼마', 1.5805),
#   ('무인도', 1.5739),
#   ('이용', 1.5713),
#   ('재료', 1.5687),
#   ('랭크', 1.5682),
#   ('렉이', 1.5619),
#   ('단순', 1.5585),
#   ('무력', 1.5536),
#   ('건장', 1.5518999999999998),
#   ('검문소', 1.5471),
#   ('중독', 1.5429000000000002),
#   ('횟수', 1.5422),
#   ('정신', 1.5414999999999999),
#   ('실수', 1.5322),
#   ('보너스', 1.5320999999999998),
#   ('일러스트', 1.5279000000000003),
#   ('유져', 1.5196999999999998),
#   ('리얼', 1.5192999999999999),
#   ('로그', 1.5173999999999999),
#   ('아웃', 1.4994),
#   ('저격', 1.4978),
#   ('버프', 1.4976),
#   ('행템이', 1.4903),
#   ('가관', 1.4853),
#   ('화이트', 1.4832),
#   ('초보자', 1.4815),
#   ('선물', 1.4778),
#   ('버전', 1.4735),
#   ('파괴', 1.4734000000000003),
#   ('답장', 1.4728),
#   ('난리', 1.4611999999999998),
#   ('부담', 1.4606),
#   ('사이', 1.4504000000000001),
#   ('아템', 1.4322),
#   ('아이디', 1.4315),
#   ('이것저것', 1.4265),
#   ('발견', 1.4203000000000001),
#   ('결제', 1.4186),
#   ('템이', 1.4161000000000001),
#   ('가위바위보', 1.4104),
#   ('정상', 1.406),
#   ('운빨겜', 1.3997),
#   ('포기', 1.3938000000000001),
#   ('추천', 1.3922),
#   ('시도', 1.3892),
#   ('소유', 1.3887999999999998),
#   ('인정', 1.3814),
#   ('초반', 1.3731),
#   ('최고', 1.37),
#   ('실제', 1.3694),
#   ('신경', 1.3679999999999999),
#   ('극악', 1.3626),
#   ('배경', 1.3578999999999999),
#   ('당시', 1.3548),
#   ('ui', 1.3543),
#   ('노래', 1.3482),
#   ('게이지', 1.3454000000000002),
#   ('해파리', 1.3445999999999998),
#   ('이따구', 1.3435),
#   ('거지', 1.3434),
#   ('오락실', 1.3404),
#   ('시대', 1.3391000000000002),
#   ('릴리스', 1.3385),
#   ('튜토', 1.3377000000000001),
#   ('전과', 1.3363),
#   ('대부분', 1.336),
#   ('아그네스', 1.3281),
#   ('무용지물', 1.3279),
#   ('강탈', 1.3276999999999999),
#   ('느낌', 1.3268),
#   ('표기', 1.3250000000000002),
#   ('공지', 1.3215000000000001),
#   ('카운터', 1.3206),
#   ('오랫만', 1.3199),
#   ('특정', 1.3114),
#   ('레무스', 1.2952),
#   ('송편', 1.2929),
#   ('네트워크', 1.2913000000000001),
#   ('조치', 1.2904),
#   ('정리', 1.2850000000000001),
#   ('준비', 1.2834),
#   ('색깔', 1.2815),
#   ('순간', 1.2787000000000002),
#   ('혜자', 1.2695),
#   ('현금', 1.2618),
#   ('본질', 1.2543000000000002),
#   ('클래스', 1.2539000000000002),
#   ('정보', 1.2506),
#   ('인생', 1.2449),
#   ('가량', 1.2449),
#   ('특성', 1.2447),
#   ('콜라', 1.244),
#   ('인간', 1.2431),
#   ('자리', 1.2416),
#   ('주세', 1.241),
#   ('초월', 1.2396999999999998),
#   ('아래', 1.2379),
#   ('유튜브', 1.2299),
#   ('도입', 1.2269999999999999),
#   ('클로버', 1.2238000000000002),
#   ('라이트', 1.2231999999999998),
#   ('한번', 1.2228999999999999),
#   ('관리', 1.2227999999999999),
#   ('순서', 1.2225000000000001),
#   ('모바일', 1.2214),
#   ('로딩', 1.2072),
#   ('후회', 1.2064),
#   ('메뉴얼', 1.1997),
#   ('대여', 1.1989999999999998),
#   ('스펙', 1.196),
#   ('감소', 1.186),
#   ('여기저기', 1.1818),
#   ('거리', 1.177),
#   ('예상', 1.176),
#   ('최강', 1.1729),
#   ('비용', 1.1726),
#   ('차원', 1.1724),
#   ('행운템', 1.1519),
#   ('부팅', 1.1498),
#   ('연희', 1.1488),
#   ('건의', 1.1471),
#   ('무과금유저', 1.1442),
#   ('점검', 1.1437),
#   ('탈출', 1.1435),
#   ('규모', 1.1433),
#   ('불가', 1.1427),
#   ('바퀴', 1.1389),
#   ('적합', 1.1360999999999999),
#   ('의미', 1.1339),
#   ('싸움', 1.1337),
#   ('매판', 1.1266),
#   ('이하', 1.1255000000000002),
#   ('대결', 1.125),
#   ('우승', 1.1215000000000002),
#   ('평준', 1.1213),
#   ('공평', 1.1194),
#   ('우주', 1.1159),
#   ('비행기', 1.1097000000000001),
#   ('본인', 1.1061999999999999),
#   ('여부', 1.1035),
#   ('페이트', 1.0985),
#   ('에러', 1.0968),
#   ('기종', 1.0965),
#   ('패밀리', 1.0943999999999998),
#   ('활용', 1.0878),
#   ('헹템', 1.0849),
#   ('클로', 1.0782),
#   ('상향', 1.0748),
#   ('티어', 1.0729),
#   ('장르', 1.0716999999999999),
#   ('약간', 1.0706),
#   ('발전', 1.069),
#   ('매너', 1.0684),
#   ('최소한', 1.0677),
#   ('역전', 1.0668),
#   ('중요', 1.0635),
#   ('수락', 1.0617),
#   ('대칭', 1.0613000000000001),
#   ('모양', 1.0611000000000002),
#   ('처리', 1.0529),
#   ('전용', 1.0495999999999999),
#   ('슈즈', 1.0476),
#   ('숫자', 1.0385),
#   ('면제', 1.0377),
#   ('오픈', 1.0367000000000002),
#   ('해당', 1.0344),
#   ('보관', 1.034),
#   ('절반', 1.0307),
#   ('이벤', 1.0254),
#   ('학교', 1.0227),
#   ('그래픽', 1.0211999999999999),
#   ('오후', 1.0201),
#   ('걱정', 1.0188),
#   ('신캐릭', 1.0187),
#   ('허무', 1.0181),
#   ('마법', 1.0177),
#   ('기술', 1.0150000000000001),
#   ('순위', 1.0109),
#   ('강조', 1.0103),
#   ('개념', 1.01),
#   ('디자인', 1.0097),
#   ('구성', 1.0095999999999998),
#   ('기원', 1.0091),
#   ('안정', 1.0075),
#   ('만큼', 1.006),
#   ('행템으', 1.0043),
#   ('허수아비', 1.0003),
#   ('기차맵', 0.9999),
#   ('캐릭과', 0.9992),
#   ('신호', 0.9965999999999999),
#   ('속박', 0.9964999999999999),
#   ('메인', 0.9934000000000001),
#   ('광고', 0.9934000000000001),
#   ('루시드', 0.9912),
#   ('진심', 0.9892000000000001),
#   ('실버', 0.9869999999999999),
#   ('전부', 0.9852000000000001),
#   ('니르바나', 0.9851),
#   ('이틀', 0.9813000000000001),
#   ('정수', 0.9789),
#   ('개빡쳐요', 0.9743),
#   ('호출', 0.974),
#   ('몇몇', 0.9727999999999999),
#   ('리치', 0.9714),
#   ('종류', 0.9702999999999999),
#   ('일정', 0.9681),
#   ('홀수', 0.9632000000000001),
#   ('섭종', 0.9624999999999999),
#   ('신의손', 0.9621000000000001),
#   ('얼음', 0.9571000000000001),
#   ('환장', 0.9551000000000001),
#   ('구매', 0.9527),
#   ('덱시스탬이', 0.9522),
#   ('후공', 0.9504999999999999),
#   ('캐릭은', 0.942),
#   ('첫판', 0.9419000000000001),
#   ('회수', 0.9397),
#   ('지옥', 0.9393),
#   ('어제', 0.9383),
#   ('템못얻어여', 0.937),
#   ('제외', 0.9355),
#   ('원활', 0.9343),
#   ('전환', 0.9336),
#   ('플레티넘', 0.9327),
#   ('되버려요', 0.9306),
#   ('보조옵', 0.9279),
#   ('티켓', 0.9259999999999999),
#   ('반성', 0.9194),
#   ('단계', 0.9174),
#   ('경기', 0.9121),
#   ('지불', 0.9095),
#   ('참가', 0.9055),
#   ('튕기기까자', 0.9039),
#   ('개편', 0.9037999999999999),
#   ('인터페이스', 0.9023),
#   ('보드', 0.9016),
#   ('약관', 0.8998),
#   ('상대편', 0.8943),
#   ('이따구로', 0.8924000000000001),
#   ('제자리', 0.8906999999999999),
#   ('손해', 0.8896999999999999),
#   ('혜택', 0.8862),
#   ('노력', 0.8861),
#   ('다트', 0.8851),
#   ('템빨로', 0.8839),
#   ('카카오톡', 0.8832),
#   ('콕스', 0.8824000000000001),
#   ('규칙', 0.8776999999999999),
#   ('오버', 0.8763000000000001),
#   ('지역', 0.873),
#   ('작년', 0.8725),
#   ('얷다고', 0.8698),
#   ('절대', 0.8696),
#   ('비눗방울', 0.8654999999999999),
#   ('아무것', 0.8613999999999999),
#   ('만약', 0.8607),
#   ('보물', 0.8603000000000001),
#   ('화이팅', 0.8569),
#   ('출첵다', 0.8506),
#   ('중급', 0.8501),
#   ('장문', 0.8492),
#   ('이코노미', 0.8485),
#   ('캐여서', 0.8466),
#   ('모서리', 0.8445),
#   ('태도', 0.8436),
#   ('낭비', 0.8435),
#   ('할인', 0.841),
#   ('지인', 0.8394),
#   ('인원수', 0.8386),
#   ('기차견비소', 0.8381),
#   ('투전', 0.8378),
#   ('행템빨로', 0.8341),
#   ('홧팅', 0.8338),
#   ('방해', 0.8334),
#   ('로테이션', 0.8316),
#   ('지경', 0.8302),
#   ('같습니디', 0.8289),
#   ('개사기행템들', 0.8286),
#   ('짓거리', 0.8269),
#   ('메롱충', 0.8230999999999999),
#   ('다크앙투아네트', 0.823),
#   ('안했스', 0.8223),
#   ('정확', 0.8213),
#   ('먼지', 0.8206),
#   ('습득', 0.8204),
#   ('버벅거리고', 0.8199),
#   ('소용', 0.8193999999999999),
#   ('엡뎃', 0.8182),
#   ('그사기캐', 0.817),
#   ('호구닌까', 0.8153),
#   ('팬레터', 0.8143),
#   ('챔스', 0.8142),
#   ('히든캐릭', 0.8122),
#   ('진화윤랑', 0.8121),
#   ('캐릭타가', 0.8118),
#   ('동시', 0.8110999999999999),
#   ('제작자', 0.8105),
#   ('바보', 0.8103),
#   ('소망', 0.8075000000000001),
#   ('노현질러', 0.8065),
#   ('행템은', 0.8064),
#   ('평생', 0.8053),
#   ('히더', 0.8047),
#   ('아놔', 0.8035),
#   ('초기화되서', 0.8035),
#   ('겜하니', 0.803),
#   ('앙투아네트', 0.8014),
#   ('보석덱', 0.801),
#   ('하위', 0.7995),
#   ('엣지', 0.7987),
#   ('어플', 0.7972),
#   ('개수', 0.7971999999999999),
#   ('즈기여', 0.7971),
#   ('대처', 0.7966),
#   ('부활', 0.796),
#   ('자기캐릭이', 0.7958),
#   ('그쪽', 0.7946),
#   ('다크앙투아', 0.7916),
#   ('머리', 0.7863),
#   ('최대', 0.7863),
#   ('개사기캐', 0.7858),
#   ('천찢', 0.7847),
#   ('꼬우', 0.7799),
#   ('사진', 0.7799),
#   ('평가', 0.779),
#   ('안주', 0.7785),
#   ('아이템빨로', 0.7749),
#   ('제밌고', 0.7741),
#   ('실망감', 0.7736),
#   ('늗데', 0.7717),
#   ('아디', 0.7714),
#   ('주시다뇨', 0.7686),
#   ('글러브', 0.768),
#   ('발휘', 0.766),
#   ('출발역', 0.7618),
#   ('유료', 0.7613000000000001),
#   ('확신', 0.7608999999999999),
#   ('장소', 0.7605999999999999),
#   ('똥망겜', 0.7583),
#   ('앙뚜아네트', 0.7581),
#   ('하눈거', 0.7578),
#   ('의도', 0.7551),
#   ('뜨길레', 0.7549),
#   ('힘듦', 0.7534000000000001),
#   ('퀄리티', 0.7531),
#   ('각성캐릭', 0.7526),
#   ('아이', 0.7515),
#   ('이올린', 0.7511),
#   ('하서', 0.751),
#   ('ㅣ송', 0.7504),
#   ('인식', 0.7502),
#   ('섬멸', 0.7498),
#   ('지게', 0.7476),
#   ('축하', 0.7474000000000001),
#   ('패캐지', 0.7465),
#   ('새벽', 0.7463),
#   ('창렬겜', 0.7417),
#   ('융뜡', 0.7393),
#   ('광팬', 0.7389),
#   ('롤랑', 0.7386),
#   ('종이', 0.7378),
#   ('클레오파트라', 0.7359),
#   ('신헹템', 0.7309),
#   ('꼴랑', 0.7297),
#   ('희망', 0.729),
#   ('추억팔이', 0.729),
#   ('플레', 0.7277),
#   ('밴런스', 0.7275),
#   ('만고', 0.7263),
#   ('같은캐릭', 0.7251),
#   ('퇴장', 0.7226),
#   ('캐릭차이', 0.7201),
#   ('목록', 0.7199),
#   ('억지', 0.7195),
#   ('각성탬', 0.7192),
#   ('행템과', 0.7169),
#   ('접속자', 0.7141),
#   ('남편', 0.7137),
#   ('흑우', 0.7137),
#   ('아서', 0.7126),
#   ('리그전', 0.7121),
#   ('해제', 0.7101999999999999),
#   ('모마듀토리얼도', 0.7082),
#   ('챔프', 0.7073),
#   ('지급', 0.7066),
#   ('중상위', 0.7061),
#   ('듀토리얼', 0.7061),
#   ('업뎃된거', 0.7049),
#   ('유의', 0.7049),
#   ('폭주', 0.7045),
#   ('다수', 0.7031000000000001),
#   ('띵작', 0.7023),
#   ('빙판', 0.7019),
#   ('숙지', 0.6994),
#   ('검색', 0.6994),
#   ('닌자', 0.6987),
#   ('행템달', 0.6983),
#   ('짝수', 0.6983),
#   ('광복절', 0.6965),
#   ('흔캐', 0.6964),
#   ('수치', 0.6960999999999999),
#   ('탬도', 0.6944),
#   ('올스텟', 0.6939),
#   ('슬기', 0.6926),
#   ('최강캐들', 0.6924),
#   ('중수로', 0.6924),
#   ('판타지', 0.6897),
#   ('나와야되서', 0.6884),
#   ('마이', 0.6881),
#   ('수익', 0.687),
#   ('랜마', 0.6863),
#   ('메일', 0.6862),
#   ('양해', 0.6859),
#   ('개빡', 0.6851),
#   ('매각', 0.6836),
#   ('결재', 0.6826),
#   ('제덱으', 0.6818),
#   ('보라', 0.6808),
#   ('직행', 0.6797),
#   ('셍거', 0.6783),
#   ('맞이', 0.6773),
#   ('막강', 0.6746),
#   ('찰나', 0.6741),
#   ('과녁', 0.6726),
#   ('당사자', 0.6712),
#   ('넋두리', 0.671),
#   ('누적', 0.6708),
#   ('서도', 0.6707),
#   ('플래', 0.6705),
#   ('전후', 0.6685),
#   ('메롱이', 0.6683),
#   ('개빡치네', 0.6678),
#   ('초과', 0.6675),
#   ('표정', 0.6668),
#   ('업체', 0.6657),
#   ('탈모', 0.665),
#   ('무템', 0.6636),
#   ('물론', 0.6626),
#   ('주컨뜨', 0.6621),
#   ('부정', 0.6619999999999999),
#   ('상상', 0.6616),
#   ('공방', 0.6615),
#   ('마스트', 0.6608),
#   ('도면', 0.6606),
#   ('시전', 0.6606),
#   ('조각', 0.66),
#   ('카페', 0.6588),
#   ('지출', 0.6575),
#   ('bot', 0.6558),
#   ('개성', 0.6555),
#   ('코인', 0.6555),
#   ('안녕', 0.6552),
#   ('상대랜마', 0.6551),
#   ('출쳌', 0.6548),
#   ('르블랑', 0.6534),
#   ('이상하', 0.6528),
#   ('그간', 0.6521),
#   ('케릭터빨', 0.651),
#   ('찬스', 0.6508),
#   ('독보', 0.6498),
#   ('크리스마스', 0.6483),
#   ('혈압', 0.648),
#   ('템빨이', 0.6465),
#   ('운빨로', 0.6465),
#   ('전자기', 0.6456),
#   ('퍼로', 0.6454),
#   ('뭔닙까', 0.6454),
#   ('저녁', 0.6453),
#   ('괴랄', 0.6447),
#   ('꼬라지', 0.6446),
#   ('lg', 0.6439),
#   ('일부', 0.6433),
#   ('로건', 0.643),
#   ('턴째', 0.642),
#   ('타래', 0.6418),
#   ('보통', 0.6396999999999999),
#   ('먹이', 0.6371),
#   ('에바', 0.636),
#   ('종일', 0.6356),
#   ('인공', 0.6354),
#   ('70퍼랜마', 0.6349),
#   ('초심자', 0.6344),
#   ('wifi', 0.6337),
#   ('승부사', 0.6325),
#   ('대출', 0.6321),
#   ('플러스', 0.6318999999999999),
#   ('위치렉', 0.631),
#   ('흔적', 0.6303),
#   ('방치', 0.6302),
#   ('역대', 0.6288),
#   ('껏다켜', 0.6277),
#   ('다섯', 0.6277),
#   ('눈치', 0.6264),
#   ('완주', 0.6263),
#   ('플래이어', 0.626),
#   ('와파', 0.6258),
#   ('정말', 0.6239),
#   ('발란스', 0.6231),
#   ('꽃길', 0.623),
#   ('익사', 0.6215),
#   ('신행템', 0.619),
#   ('최강캐', 0.6189),
#   ('경비', 0.6189),
#   ('태블릿', 0.6187),
#   ('높혀주시', 0.6186),
#   ('좀비', 0.6184),
#   ('전도', 0.617),
#   ('리뉴얼캐', 0.6168),
#   ('모마망겜', 0.6168),
#   ('일종', 0.6166),
#   ('신랑', 0.6162),
#   ('비중', 0.6161),
#   ('허망', 0.6152),
#   ('행맵', 0.6151),
#   ('개연', 0.6142),
#   ('실력자', 0.6131),
#   ('열쇠', 0.6131),
#   ('모마로', 0.6118),
#   ('근처', 0.6106),
#   ('가지가지', 0.6096),
#   ('겜과의', 0.6091),
#   ('시너지', 0.6086),
#   ('체감', 0.608),
#   ('어처구니', 0.6078),
#   ('버벅거리며', 0.6078),
#   ('반발', 0.6067),
#   ('흥분', 0.6064),
#   ('전이', 0.6054),
#   ('배정', 0.6054),
#   ('떻게', 0.6054),
#   ('모두의마블어디갓나요', 0.6052),
#   ('스마트폰', 0.6046),
#   ('냄새', 0.6033999999999999),
#   ('스타트', 0.6031),
#   ('감흥', 0.6021),
#   ('개최', 0.6007),
#   ('진도', 0.6004),
#   ('야누스', 0.6),
#   ('노템', 0.5985),
#   ('의존도', 0.5967),
#   ('내꺼', 0.5965),
#   ('일회', 0.5955),
#   ('벨러스', 0.5941),
#   ('허바', 0.5937),
#   ('월맵', 0.5937),
#   ('슈퍼프카팩', 0.5936),
#   ('퀘스트', 0.5935),
#   ('맵도', 0.5911),
#   ('필연', 0.5908),
#   ('후회되고', 0.5905),
#   ('깊이', 0.5905),
#   ('프릴', 0.5899),
#   ('사고', 0.5893999999999999),
#   ('신규템', 0.5887),
#   ('다행', 0.5887),
#   ('온라인', 0.5886),
#   ('모마유저', 0.5884),
#   ('의향', 0.588),
#   ('핸폰', 0.5866),
#   ('메모리', 0.5844),
#   ('되버렸네요', 0.5839),
#   ('전망', 0.5838),
#   ('노트', 0.5837),
#   ('행운아', 0.5833),
#   ('똥겜', 0.5831),
#   ('본론', 0.5817),
#   ('전사', 0.5815),
#   ('종행템', 0.5811),
#   ('사용자', 0.5799000000000001),
#   ('순수', 0.5799),
#   ('심정', 0.5792),
#   ('3턴', 0.5792),
#   ('니코틴', 0.5791),
#   ('재비뽑기', 0.579),
#   ('홈파티', 0.5789),
#   ('휴대폰', 0.5784),
#   ('마나', 0.5784),
#   ('천만', 0.5783),
#   ('좀더재밋', 0.5781),
#   ('단체', 0.5781),
#   ('아이콘', 0.5768),
#   ('구역', 0.5765),
#   ('오류개', 0.5758),
#   ('금일', 0.5756),
#   ('애정', 0.5755),
#   ('꼴찌', 0.5754),
#   ('승만', 0.5751),
#   ('이러니개쳐', 0.5747),
#   ('듯이', 0.5739),
#   ('스텟', 0.5738),
#   ('활팅', 0.5738),
#   ('만족', 0.5732),
#   ('구데기라서', 0.5723),
#   ('오떻', 0.5718),
#   ('되가고', 0.5712),
#   ('리코', 0.5704),
#   ('기타', 0.5695),
#   ('전성기', 0.5693),
#   ('고급템', 0.5692),
#   ('버벅임', 0.5684),
#   ...],
#  [('유저', 68.05889999999997),
#   ('업데이트', 54.4896),
#   ('캐릭터', 43.597500000000004),
#   ('옛날', 35.316900000000004),
#   ('접속', 35.1817),
#   ('복귀', 32.729800000000004),
#   ('플레이', 30.72739999999999),
#   ('오랜만', 26.818499999999997),
#   ('몬스터', 24.793400000000002),
#   ('예전', 23.333199999999994),
#   ('재미', 22.548499999999997),
#   ('지금', 19.8425),
#   ('정도', 19.678899999999995),
#   ('시작', 19.4871),
#   ('감사', 18.716099999999997),
#   ('생각', 18.1788),
#   ('처음', 18.0959),
#   ('보상', 17.3162),
#   ('강화', 16.1903),
#   ('서버', 16.059600000000003),
#   ('난이도', 15.044),
#   ('실행', 14.1716),
#   ('이벤트', 13.7538),
#   ('요즘', 13.7515),
#   ('신장', 13.750199999999996),
#   ('수정', 13.365399999999998),
#   ('초월', 13.080000000000002),
#   ('이상', 13.0088),
#   ('삭제', 12.951699999999997),
#   ('업뎃', 12.764399999999998),
#   ('사람', 12.1524),
#   ('설치', 12.0358),
#   ('안녕하세요', 12.0022),
#   ('버전', 11.434000000000003),
#   ('현지', 11.3015),
#   ('대륙', 11.264000000000001),
#   ('오류', 10.897400000000001),
#   ('모험', 10.823099999999998),
#   ('이후', 10.766300000000001),
#   ('신규', 10.731099999999998),
#   ('기존', 10.719899999999999),
#   ('그때', 10.5029),
#   ('이것', 10.499500000000001),
#   ('필요', 9.9532),
#   ('대전', 9.825899999999999),
#   ('해결', 9.709),
#   ('시간', 9.5171),
#   ('추억', 9.423800000000002),
#   ('버튼', 9.3089),
#   ('뽑기', 9.2825),
#   ('확률', 9.2033),
#   ('반복', 9.2004),
#   ('장비', 9.1433),
#   ('현상', 8.918199999999999),
#   ('그것', 8.654800000000002),
#   ('버그', 8.515899999999998),
#   ('계정', 8.5013),
#   ('캐릭', 8.0982),
#   ('화면', 8.0175),
#   ('초기', 7.8530999999999995),
#   ('문제', 7.619299999999999),
#   ('고유', 7.397),
#   ('이번', 7.342099999999999),
#   ('파괴', 7.2215),
#   ('시절', 7.1873),
#   ('방법', 7.1769),
#   ('노트', 7.160200000000001),
#   ('오늘', 7.034399999999999),
#   ('노가다', 7.032099999999999),
#   ('확인', 7.0178),
#   ('초창기', 6.9471),
#   ('부탁', 6.832599999999999),
#   ('로그인', 6.434),
#   ('그래픽', 6.398999999999999),
#   ('자체', 6.29),
#   ('하루', 6.200899999999999),
#   ('자동', 6.154699999999999),
#   ('상태', 6.1023),
#   ('동안', 5.965800000000001),
#   ('밸런스', 5.9071),
#   ('진행', 5.834),
#   ('다운', 5.800699999999999),
#   ('종료', 5.7391),
#   ('아이템', 5.6197),
#   ('수호', 5.574),
#   ('핸드폰', 5.4786),
#   ('운영자', 5.472899999999999),
#   ('초심', 5.4592),
#   ('미나', 5.441199999999999),
#   ('성장', 5.4234),
#   ('시스템', 5.400600000000001),
#   ('갓겜', 5.3931),
#   ('퀘스트', 5.3434),
#   ('로딩', 5.2946),
#   ('때문', 5.2636),
#   ('레벨', 5.2336),
#   ('짜증', 5.120399999999999),
#   ('운영', 5.1133),
#   ('친구', 5.0797),
#   ('스토어', 4.9228),
#   ('기억', 4.8692),
#   ('패치', 4.8389),
#   ('스테이지', 4.771299999999999),
#   ('컨텐츠', 4.6352),
#   ('최신', 4.5449),
#   ('느낌', 4.486),
#   ('유도', 4.4571000000000005),
#   ('영웅', 4.4423),
#   ('현신', 4.4079),
#   ('중간', 4.4043),
#   ('제거', 4.3493),
#   ('돌파', 4.2818),
#   ('순간', 4.2789),
#   ('광고', 4.2719),
#   ('불편', 4.2629),
#   ('추가', 4.2467999999999995),
#   ('가능', 4.2081),
#   ('뉴비', 4.179600000000001),
#   ('레이드', 4.1465000000000005),
#   ('답변', 4.0556),
#   ('지역', 4.0478000000000005),
#   ('장벽', 4.039599999999999),
#   ('도감', 4.0307),
#   ('메인', 4.0229),
#   ('과금', 3.9822000000000006),
#   ('리뷰', 3.9579),
#   ('클리어', 3.9428),
#   ('던전', 3.9223),
#   ('등급', 3.8888000000000003),
#   ('가지', 3.8697),
#   ('수호신', 3.8653),
#   ('갤럭시', 3.8423999999999996),
#   ('이제', 3.8186999999999998),
#   ('열쇠', 3.816),
#   ('차원', 3.8017000000000003),
#   ('결국', 3.763),
#   ('몬길', 3.7558999999999996),
#   ('미션', 3.7522),
#   ('스킬', 3.6442999999999994),
#   ('다양', 3.6346),
#   ('깃털', 3.6032999999999995),
#   ('초딩', 3.5969),
#   ('진입', 3.5804),
#   ('조치', 3.5734),
#   ('그거', 3.5641999999999996),
#   ('부분', 3.5351999999999997),
#   ('조금', 3.4989000000000003),
#   ('재료', 3.4399),
#   ('목요일', 3.2833),
#   ('에러', 3.2637),
#   ('소리', 3.2511),
#   ('만족', 3.1681),
#   ('서슬', 3.146),
#   ('복구', 3.1344),
#   ('점검', 3.1142000000000003),
#   ('정지', 3.1126),
#   ('길드', 3.0868999999999995),
#   ('자연', 3.0699000000000005),
#   ('문구', 3.0454999999999997),
#   ('개선', 3.0443999999999996),
#   ('관리', 3.0185999999999997),
#   ('사항', 2.9896000000000003),
#   ('신캐', 2.9495),
#   ('스토리', 2.9409),
#   ('출시', 2.8771999999999998),
#   ('기분', 2.8082),
#   ('보스', 2.7967000000000004),
#   ('실패', 2.7645999999999997),
#   ('마지막', 2.7498),
#   ('거기', 2.7313),
#   ('다운로드', 2.7150999999999996),
#   ('강제', 2.6984000000000004),
#   ('닉네임', 2.6955999999999998),
#   ('일러스트', 2.684),
#   ('출석', 2.6612999999999998),
#   ('진화', 2.6267),
#   ('응원', 2.6246),
#   ('개인', 2.6214000000000004),
#   ('수호자', 2.6184000000000003),
#   ('업그레이드', 2.6172),
#   ('문의', 2.6046),
#   ('신고', 2.5968999999999998),
#   ('오랫만', 2.5919),
#   ('실망', 2.5629999999999997),
#   ('방치', 2.4951),
#   ('당황', 2.4848999999999997),
#   ('최고', 2.4846000000000004),
#   ('비비안', 2.4720999999999997),
#   ('전투', 2.4291),
#   ('옜날', 2.4278),
#   ('계속', 2.4212000000000002),
#   ('오픈', 2.4144999999999994),
#   ('케릭', 2.4071000000000002),
#   ('포식자', 2.4046000000000003),
#   ('오랫동안', 2.3953),
#   ('무한', 2.386),
#   ('기린', 2.3552999999999997),
#   ('적응', 2.3377),
#   ('인물', 2.3022),
#   ('패키지', 2.3005),
#   ('넷마블', 2.2967),
#   ('플레이어', 2.2584999999999997),
#   ('타격감', 2.2518000000000002),
#   ('경우', 2.2401),
#   ('요소', 2.2271),
#   ('요번', 2.2260999999999997),
#   ('부족', 2.1932),
#   ('마찬가지', 2.186),
#   ('각성', 2.1489000000000003),
#   ('조합', 2.1465),
#   ('발전', 2.1403),
#   ('구글', 2.1304),
#   ('최대', 2.1302),
#   ('마리', 2.1289),
#   ('등등', 2.1224),
#   ('망겜', 2.091),
#   ('응답', 2.0860000000000003),
#   ('무과금유저', 2.0793),
#   ('쓰레기', 2.0413),
#   ('이유', 2.0355),
#   ('자기', 2.0278),
#   ('쿠키런', 2.0208),
#   ('장난', 1.9935),
#   ('합성', 1.9916),
#   ('기종', 1.9802),
#   ('횟수', 1.9746),
#   ('완료', 1.9676999999999998),
#   ('사용', 1.9629),
#   ('재화', 1.9586999999999999),
#   ('능력', 1.9520000000000002),
#   ('세븐나이츠', 1.9463),
#   ('환불', 1.9432999999999998),
#   ('네트워크', 1.9335),
#   ('상황', 1.9295),
#   ('댓글', 1.925),
#   ('기본', 1.9160000000000001),
#   ('여기', 1.8997000000000002),
#   ('수고', 1.8877000000000002),
#   ('노출', 1.8872),
#   ('서비스', 1.8865000000000003),
#   ('이펙트', 1.876),
#   ('주년', 1.8683),
#   ('시일', 1.856),
#   ('안정', 1.8492),
#   ('선택', 1.8327),
#   ('설정', 1.8283),
#   ('주일', 1.8209),
#   ('이전', 1.8064),
#   ('육성', 1.8062),
#   ('정보', 1.8058),
#   ('이해', 1.8048),
#   ('그림', 1.7965),
#   ('약간', 1.7858999999999998),
#   ('정상', 1.7845999999999997),
#   ('무과', 1.7843),
#   ('칭찬', 1.7827),
#   ('한계', 1.7800999999999998),
#   ('전체', 1.7799),
#   ('등장', 1.7731),
#   ('년도', 1.7660999999999998),
#   ('부활', 1.7639),
#   ('진짜', 1.763),
#   ('휴대폰', 1.7603999999999997),
#   ('단계', 1.7485),
#   ('팅기', 1.7427000000000001),
#   ('언제', 1.7416),
#   ('단점', 1.7365000000000002),
#   ('캐릭이', 1.7268),
#   ('중단', 1.7227000000000001),
#   ('습지', 1.7121),
#   ('향수', 1.71),
#   ('새벽', 1.7065000000000001),
#   ('기대', 1.6955999999999998),
#   ('베르', 1.6894),
#   ('조정', 1.6768999999999998),
#   ('개발자', 1.6542000000000001),
#   ('의미', 1.6508999999999998),
#   ('마음', 1.6417),
#   ('카톡', 1.6378),
#   ('제련', 1.6376),
#   ('나중', 1.6344999999999998),
#   ('아빠', 1.6323),
#   ('다음', 1.6286),
#   ('잠금', 1.6153),
#   ('설명', 1.6105),
#   ('당시', 1.6088),
#   ('아이', 1.6034000000000002),
#   ('추천', 1.5897999999999999),
#   ('한번', 1.5765),
#   ('사정', 1.5738),
#   ('리소스', 1.5612),
#   ('시도', 1.557),
#   ('신비', 1.5405),
#   ('캐릭을', 1.5394999999999999),
#   ('문제점', 1.5375),
#   ('노력', 1.5289),
#   ('한정', 1.5238),
#   ('랭커', 1.5222),
#   ('조각', 1.5192999999999999),
#   ('배경', 1.5167000000000002),
#   ('제한', 1.5131000000000001),
#   ('초반', 1.5039),
#   ('화이팅', 1.5014),
#   ('추억팔이', 1.4979),
#   ('카카오톡', 1.4768999999999999),
#   ('초보', 1.4764),
#   ('플립', 1.4692),
#   ('기기', 1.4593),
#   ('다수', 1.4224),
#   ('유아이', 1.4178),
#   ('증상', 1.4163000000000001),
#   ('이름', 1.4131),
#   ('rpg', 1.4112),
#   ('노래', 1.4108),
#   ('어플', 1.4077),
#   ('방식', 1.4054),
#   ('몬길유저', 1.3976000000000002),
#   ('마련', 1.3927),
#   ('종일', 1.3923),
#   ('경쟁', 1.3872),
#   ('건의', 1.3841),
#   ('건강', 1.3802),
#   ('벨런스', 1.3765),
#   ('당연', 1.3713),
#   ('언급', 1.3644),
#   ('섭종', 1.3593000000000002),
#   ('출첵', 1.3578999999999999),
#   ('비교', 1.3445),
#   ('용량', 1.3437999999999999),
#   ('기능', 1.3408),
#   ('표시', 1.3302),
#   ('알림', 1.3287),
#   ('초등학생', 1.3252000000000002),
#   ('ui', 1.3211),
#   ('요청', 1.3192),
#   ('불멸', 1.3000999999999998),
#   ('열기', 1.2974999999999999),
#   ('고생', 1.2908),
#   ('나이', 1.2798),
#   ('아무것', 1.2765),
#   ('정작', 1.2729),
#   ('체력', 1.2669000000000001),
#   ('아이디', 1.2654),
#   ('회복', 1.2649),
#   ('쎈캐', 1.2642),
#   ('안드로이드', 1.2588),
#   ('연속', 1.2582),
#   ('지속', 1.2523),
#   ('정신', 1.2463000000000002),
#   ('내용', 1.2389000000000001),
#   ('회사', 1.2366),
#   ('연결', 1.2335),
#   ('기록', 1.2313999999999998),
#   ('신경', 1.2147000000000001),
#   ('공지', 1.2061000000000002),
#   ('팅겨서', 1.1985000000000001),
#   ('상대', 1.1943),
#   ('클릭', 1.1856),
#   ('수준', 1.1848999999999998),
#   ('달성', 1.1789999999999998),
#   ('멤버', 1.1764000000000001),
#   ('중딩', 1.1688999999999998),
#   ('인증', 1.1652),
#   ('어려움', 1.165),
#   ('관심', 1.1562999999999999),
#   ('가입', 1.1528),
#   ('성인', 1.1491),
#   ('게인', 1.1482999999999999),
#   ('남자', 1.1442),
#   ('구매', 1.139),
#   ('무과금', 1.1346),
#   ('고급', 1.1336),
#   ('클래식', 1.1308),
#   ('나름', 1.1276),
#   ('카카오', 1.1274),
#   ('작동', 1.1251000000000002),
#   ('와이파이', 1.1242999999999999),
#   ('지급', 1.1229999999999998),
#   ('영혼', 1.1227),
#   ('불만', 1.1196000000000002),
#   ('무기', 1.1195),
#   ('수련', 1.1163),
#   ('유적', 1.1148),
#   ('발생', 1.1079),
#   ('완벽', 1.1073),
#   ('요일', 1.1071),
#   ('사이', 1.107),
#   ('반영', 1.1066),
#   ('재밋', 1.1065),
#   ('주인공', 1.1064),
#   ('코스튬', 1.1058),
#   ('쓸모', 1.1028),
#   ('베르나서버', 1.1019),
#   ('세트', 1.0974),
#   ('전락', 1.0967),
#   ('구간', 1.0941),
#   ('기간', 1.093),
#   ('신장캐릭', 1.0857),
#   ('성공', 1.0819999999999999),
#   ('유튜브', 1.0733),
#   ('그날', 1.0731),
#   ('퀄리티', 1.0695000000000001),
#   ('개월', 1.0649),
#   ('대기', 1.0647),
#   ('보석', 1.0642999999999998),
#   ('장소', 1.0615999999999999),
#   ('항목', 1.0613000000000001),
#   ('석도', 1.0564),
#   ('데이트', 1.0541),
#   ('우리', 1.0537),
#   ('형식', 1.048),
#   ('각인', 1.0457999999999998),
#   ('나머지', 1.0455),
#   ('최악', 1.0434),
#   ('제시', 1.04),
#   ('구조', 1.0395),
#   ('화염', 1.038),
#   ('핸폰', 1.0365),
#   ('상향', 1.0324),
#   ('조건', 1.0322),
#   ('누구', 1.0258),
#   ('초보자', 1.0257),
#   ('유입', 1.0236),
#   ('확장', 1.0228),
#   ('암흑', 1.0212),
#   ('완성', 1.0174),
#   ('개떡', 1.007),
#   ('플러스', 1.0034),
#   ('수동', 1.0025),
#   ('우편함', 0.9990000000000001),
#   ('모습', 0.9969),
#   ('모드', 0.9961),
#   ('극악', 0.996),
#   ('코드', 0.9957),
#   ('사냥', 0.9953000000000001),
#   ('버젼', 0.9899),
#   ('특수', 0.9898),
#   ('연장', 0.9813000000000001),
#   ('콘텐츠', 0.9807),
#   ('공간', 0.9796),
#   ('사랑', 0.9794),
#   ('전투력', 0.9757),
#   ('장착', 0.9739),
#   ('젤재밋게', 0.9721),
#   ('빡시네요', 0.9709),
#   ('카페', 0.9703999999999999),
#   ('저장', 0.9641),
#   ('인기', 0.9605),
#   ('마을', 0.9594),
#   ('입장', 0.9590000000000001),
#   ('카드', 0.9553),
#   ('결제', 0.9521),
#   ('홧팅', 0.9512),
#   ('점줌요', 0.948),
#   ('획득', 0.9454),
#   ('과거', 0.9437),
#   ('성뽑갯내여', 0.9409),
#   ('공격', 0.9351),
#   ('하느테이지', 0.93),
#   ('모양', 0.9292),
#   ('몄몄', 0.9284),
#   ('베르나', 0.9283),
#   ('복귀퀘스트', 0.9254),
#   ('인생', 0.9240999999999999),
#   ('중복', 0.9215),
#   ('입력', 0.9188999999999999),
#   ('리턴즈', 0.9186000000000001),
#   ('쳐팅기', 0.9159),
#   ('제밌음', 0.9155),
#   ('아쥬', 0.9082),
#   ('핵과금러', 0.9059),
#   ('invalid', 0.9048),
#   ('제작자', 0.9031),
#   ('업뎃은', 0.9027),
#   ('코스튬이', 0.9),
#   ('입맛', 0.8995),
#   ('최소', 0.8967),
#   ('계획', 0.8963),
#   ('애정', 0.8956999999999999),
#   ('상위랭커에', 0.8942),
#   ('맨팅기고', 0.894),
#   ('팅기는거', 0.8938),
#   ('인터넷', 0.893),
#   ('최근', 0.8917),
#   ('캐릭이여', 0.8908),
#   ('몬길러', 0.8889),
#   ('유지', 0.8885),
#   ('조절', 0.8860999999999999),
#   ('유행', 0.8851),
#   ('갓겜이였늣데', 0.8798),
#   ('삭제요', 0.8797),
#   ('거지', 0.8785),
#   ('된어요', 0.873),
#   ('선물', 0.8687),
#   ('개편', 0.8679999999999999),
#   ('사건', 0.867),
#   ('업대이트', 0.8666),
#   ('계기', 0.8654),
#   ('왓파', 0.8654),
#   ('도중', 0.8562),
#   ('업뎃하셈', 0.8547),
#   ('다시나왔스먄', 0.8537),
#   ('하내', 0.8531),
#   ('결론', 0.8518),
#   ('시기', 0.8487),
#   ('리뉴얼', 0.8483),
#   ('재밋어요', 0.8431),
#   ('즐겨찾기', 0.8417),
#   ('게임캐릭', 0.8405),
#   ('마일리지', 0.8368),
#   ('전이', 0.8365),
#   ('처리', 0.8362),
#   ('검색', 0.8331999999999999),
#   ('골드', 0.8327),
#   ('되요', 0.8319),
#   ('컨트롤', 0.8309),
#   ('어잆네', 0.83),
#   ('동일', 0.8298000000000001),
#   ('공기', 0.8286),
#   ('해제', 0.8271999999999999),
#   ('비주얼', 0.8259),
#   ('소모', 0.8256),
#   ('만큼', 0.8243),
#   ('아나', 0.8226),
#   ('붕괴', 0.8215),
#   ('고인', 0.818),
#   ('방향', 0.8179000000000001),
#   ('욜띰히', 0.8107),
#   ('강화햐야', 0.8102),
#   ('세쿨럭븐에헴나크헴이읏헴츠', 0.8094),
#   ('얼마', 0.8075),
#   ('고쳐주샸', 0.8063),
#   ('도전', 0.8062),
#   ('세상', 0.8051),
#   ('꾸중', 0.8047),
#   ('체크', 0.8026),
#   ('사기', 0.7998000000000001),
#   ('소몯힜', 0.7998),
#   ('좋은캐쓰네요', 0.7965),
#   ('혜택', 0.7963),
#   ('현금', 0.7947),
#   ('우주', 0.7944),
#   ('개꿀잼임', 0.7929),
#   ('흑우겜', 0.7921),
#   ('기회', 0.7919),
#   ('결과', 0.7908),
#   ('한판', 0.7889999999999999),
#   ('기고', 0.784),
#   ('버프', 0.782),
#   ('오전', 0.7775),
#   ('캐릭으', 0.7774),
#   ('뚜레기', 0.7773),
#   ('이용', 0.7746999999999999),
#   ('특정', 0.7745),
#   ('중학', 0.7744),
#   ('잠깐', 0.774),
#   ('실상', 0.7727),
#   ('정말', 0.7696),
#   ('전장', 0.7688),
#   ('다른캐', 0.7675),
#   ('원래', 0.7642),
#   ('개발', 0.7629),
#   ('헨폰', 0.762),
#   ('올데이올나잇', 0.7598),
#   ('쓰래기', 0.7592),
#   ('브롤스타즈', 0.759),
#   ('경치', 0.7589),
#   ('개꿀잼이', 0.7571),
#   ('원년', 0.7567),
#   ('첫플래이', 0.7561),
#   ('복귀러', 0.7539),
#   ('아슈', 0.7531),
#   ('교체', 0.7519),
#   ('상점', 0.7497),
#   ('저거', 0.7496),
#   ('대학', 0.7488),
#   ('저번', 0.7472),
#   ('다행', 0.7469),
#   ('꿀잼여', 0.7441),
#   ('무과금러', 0.7376),
#   ('학년', 0.7361),
#   ('따위', 0.7344),
#   ('배터리', 0.7329),
#   ('업테이트', 0.7326),
#   ('챀가', 0.7316),
#   ('미안', 0.7297),
#   ('한복삘', 0.7294),
#   ('클라우드', 0.7259),
#   ('개판', 0.7254),
#   ('코스튬과', 0.725),
#   ('변한', 0.723),
#   ('캐릭다', 0.7226),
#   ('엄마', 0.7225),
#   ('의견', 0.7222),
#   ('물거품', 0.7221),
#   ('리메이크', 0.7209),
#   ('하지마셈', 0.7207),
#   ('개성', 0.7204999999999999),
#   ('애초', 0.7204),
#   ('콜라', 0.7189),
#   ('반응', 0.7162999999999999),
#   ('재밋게', 0.7155),
#   ('팀버프', 0.7153),
#   ('조작', 0.7152),
#   ('레이스', 0.7145),
#   ('꼬지', 0.7142),
#   ('전무', 0.7137),
#   ('처음처럼', 0.7132),
#   ('hh', 0.7127),
#   ('평타', 0.7111),
#   ('인간', 0.7102),
#   ('활성', 0.7082999999999999),
#   ('께야되', 0.7081),
#   ('야홍', 0.7077),
#   ('추억에브', 0.7065),
#   ('담당', 0.7063),
#   ('재접과', 0.706),
#   ('애착', 0.7058),
#   ('이밴트', 0.7057),
#   ('몬길때', 0.7044),
#   ('렉이', 0.7032),
#   ('관전', 0.7022),
#   ('스타크래프트', 0.7019),
#   ('유진', 0.7009),
#   ('흑우', 0.7006),
#   ('후반', 0.6996),
#   ('아쉬움', 0.6991),
#   ('빠쁨니', 0.6984),
#   ('퀘는', 0.6983),
#   ('업데', 0.697),
#   ('무과금에', 0.6965),
#   ('난무', 0.6961),
#   ('개꿀잼', 0.696),
#   ('중국', 0.6917),
#   ('여한', 0.6911),
#   ('담당자', 0.6886),
#   ('통화', 0.6886),
#   ('완전', 0.6885),
#   ('길드워', 0.688),
#   ('얘기', 0.6868),
#   ('행복', 0.6868),
#   ('적기', 0.6853),
#   ('대우', 0.6844),
#   ('상대방', 0.6834),
#   ('방어', 0.6833),
#   ('이밴트때', 0.6832),
#   ('몬길리마스터', 0.683),
#   ('통합', 0.6820999999999999),
#   ('초등학교', 0.681),
#   ('짜리', 0.6806),
#   ('포획', 0.6805),
#   ('장신구', 0.68),
#   ('모늗', 0.6795),
#   ('여건', 0.6776),
#   ('그레도', 0.6763),
#   ('종이', 0.6761),
#   ('팅겨', 0.6753),
#   ('역대', 0.6728),
#   ('충고', 0.6716),
#   ('소프트웨어', 0.6716),
#   ('구서버', 0.6695),
#   ('android', 0.6675),
#   ('전설템', 0.6673),
#   ('어둠', 0.6671),
#   ('하향', 0.6669),
#   ('비번', 0.6667),
#   ('시공', 0.6658),
#   ('배려', 0.665),
#   ('티아', 0.6647),
#   ('적용', 0.663),
#   ('어이', 0.6619),
#   ('중지', 0.6619),
#   ('파일', 0.6611),
#   ('릴리', 0.6598),
#   ('평소', 0.6595),
#   ('박살', 0.6585),
#   ('나이츠크로니땡', 0.6584),
#   ('대한민국', 0.6584),
#   ('천만', 0.6581),
#   ('싸구려', 0.6568),
#   ('오버벨런스네요', 0.6555),
#   ('반석', 0.6543),
#   ('벨런스가', 0.6542),
#   ('멘트', 0.6541),
#   ('한국인', 0.6527),
#   ('로그', 0.6523),
#   ('염려', 0.6515),
#   ('한국', 0.6514),
#   ('gamekey', 0.6514),
#   ('제밌', 0.6512),
#   ('관리자', 0.6502),
#   ('몬길러미', 0.6502),
#   ('제에바알', 0.6498),
#   ('즐몬', 0.6494),
#   ('후속작', 0.6493),
#   ('어머니', 0.6484),
#   ('파수', 0.6479),
#   ('상위랭커', 0.6473),
#   ('우리나라', 0.6459),
#   ('성급', 0.6453),
#   ('인대', 0.6448),
#   ('시대', 0.6435),
#   ('부적', 0.6426),
#   ('충성', 0.642),
#   ('저희', 0.6409),
#   ('폐치', 0.6397),
#   ('서포터', 0.6396),
#   ('먹이', 0.6379),
#   ('풍월주', 0.6355),
#   ('슬라', 0.6349),
#   ('시정', 0.6347),
#   ('유튭', 0.6322),
#   ('강종', 0.631),
#   ('업댓', 0.6294),
#   ('발표', 0.6289),
#   ('리치', 0.6286),
#   ('일대', 0.6283),
#   ('요즈음', 0.628),
#   ('공감', 0.6278),
#   ('편중', 0.6252),
#   ('총사', 0.6249),
#   ('우선', 0.6241),
#   ('오래전', 0.6237),
#   ('포기', 0.6234),
#   ('임펙트', 0.6224),
#   ('적합', 0.6221),
#   ('로봇', 0.6212),
#   ('최애', 0.6197),
#   ('브레이크', 0.6162),
#   ('과다', 0.6158),
#   ('아옭킹', 0.6147),
#   ('휼륭', 0.6126),
#   ('블루스', 0.6115),
#   ('이틀', 0.6114),
#   ('스포', 0.6107),
#   ('구경', 0.61),
#   ('parameter', 0.6082),
#   ('거갯', 0.6069),
#   ('꼬라', 0.6062),
#   ('서버렉', 0.6055),
#   ('장도', 0.6055),
#   ('막장', 0.605),
#   ('역할', 0.6028),
#   ('돌파몬', 0.6009),
#   ('장담', 0.6002),
#   ('라이트', 0.6),
#   ('아기', 0.5981),
#   ('만년', 0.5977),
#   ('손해', 0.5972),
#   ('엄두', 0.597),
#   ('기만', 0.5958),
#   ('라임', 0.5949),
#   ('스릴', 0.5947),
#   ('정수', 0.5946),
#   ('에러뜨', 0.5941),
#   ('챌린저', 0.5939),
#   ('몬길서버', 0.5924),
#   ('사양', 0.5919),
#   ('만우절', 0.5917),
#   ('롤플레잉', 0.5888),
#   ('사진', 0.5884),
#   ('온라인', 0.5882),
#   ('다음업뎃에서', 0.5881),
#   ('대결', 0.5872),
#   ('모험가', 0.5857),
#   ('쩔수', 0.5846),
#   ('정산', 0.5835),
#   ('효자', 0.5821),
#   ('인지', 0.5817),
#   ('결장', 0.5812),
#   ('신작', 0.5808),
#   ('비등비등해야져', 0.5799),
#   ('아이콘', 0.5795),
#   ('사랑합니다', 0.5794),
#   ('렙업', 0.5777),
#   ('무어', 0.5775),
#   ('변화', 0.5769),
#   ('발전돤', 0.5746),
#   ('어림', 0.5739),
#   ('킹덤', 0.5733),
#   ('좋은캐릭', 0.5719),
#   ('하기', 0.57),
#   ('석기', 0.57),
#   ('순식간', 0.5696),
#   ('남캐', 0.5691),
#   ('전전', 0.569),
#   ('언제쯤', 0.5682),
#   ('카이얀', 0.5675),
#   ('사장', 0.5671),
#   ('1티어', 0.5666),
#   ('악마', 0.5663),
#   ('박탈감', 0.5661),
#   ('재련', 0.5653),
#   ('새캐릭을', 0.565),
#   ('다이아', 0.5649),
#   ('폰바꾸다', 0.5646),
#   ('거부', 0.5628),
#   ('가죽', 0.562),
#   ('정확', 0.5615),
#   ('창렬', 0.5615),
#   ('사탕', 0.5609),
#   ('유저인데', 0.5606),
#   ('음악', 0.5595),
#   ('장갑', 0.5589),
#   ('친절', 0.5589),
#   ('격차', 0.5588),
#   ('의도', 0.5586),
#   ('지원', 0.5581),
#   ('보장', 0.5579),
#   ('최신버젼', 0.5579),
#   ('전생', 0.5579),
#   ('동시', 0.5574),
#   ('격리', 0.5569),
#   ('즐거움', 0.5567),
#   ('도용', 0.5567),
#   ('전면', 0.5561),
#   ('다리', 0.5559),
#   ('안드로이드폰', 0.5555),
#   ('이미지', 0.5552),
#   ('메세지', 0.5532),
#   ('재대', 0.553),
#   ('디자인과', 0.5522),
#   ('만점', 0.552),
#   ('고딩', 0.5519),
#   ('여캐', 0.5517),
#   ('횡포', 0.5512),
#   ('검사', 0.5512),
#   ('버벅거림', 0.5483),
#   ('이내', 0.548),
#   ('자리', 0.5475),
#   ('신속', 0.5475),
#   ('지옥', 0.5473),
#   ('소멸', 0.5459),
#   ('프로', 0.545),
#   ('후회', 0.5443),
#   ('부담', 0.5435),
#   ('참가', 0.5434),
#   ('버퍼링', 0.5429),
#   ('정착', 0.5426),
#   ('관련', 0.5422),
#   ('위화감', 0.5412),
#   ('일일', 0.5411),
#   ('아저씨', 0.5405),
#   ('펀치', 0.5398),
#   ('기를', 0.5397),
#   ('보완', 0.5396),
#   ('별점', 0.5396),
#   ('피로감', 0.5384),
#   ('참고', 0.5373),
#   ('메시지', 0.5371),
#   ('자유도', 0.5365),
#   ('패드', 0.5362),
#   ('스킨', 0.5341),
#   ('ace', 0.5333),
#   ('치명타', 0.5324),
#   ('공공', 0.5323),
#   ('재밋고', 0.5314),
#   ('대상', 0.5302),
#   ('경쟁사', 0.5295),
#   ('귀귀', 0.5278),
#   ('같믄', 0.5273),
#   ('정성', 0.5258),
#   ('고수', 0.5256),
#   ('일반', 0.5251),
#   ('전부', 0.523),
#   ('진동', 0.5229),
#   ('params', 0.5217),
#   ('묘미', 0.5217),
#   ('혼돈', 0.5213),
#   ('사용자', 0.5208),
#   ('총점', 0.5208),
#   ('태블릿', 0.5207),
#   ('아래', 0.5203),
#   ('철회', 0.5203),
#   ('저질', 0.5195),
#   ('각각', 0.5193),
#   ('보라색', 0.5188),
#   ('한때', 0.5184),
#   ('만료', 0.5184),
#   ('현성', 0.5176),
#   ('인가', 0.5173),
#   ('반발', 0.5168),
#   ('카이저', 0.5167),
#   ('굴레', 0.5146),
#   ('루비', 0.5133),
#   ('산장', 0.5116),
#   ('해상도', 0.5116),
#   ('허무', 0.5111),
#   ('현황', 0.5108),
#   ('채팅', 0.5102),
#   ('webview', 0.5095),
#   ('카드사', 0.509),
#   ('레어', 0.509),
#   ('조화', 0.5085),
#   ('본질', 0.5084),
#   ('개똥', 0.5083),
#   ('열심', 0.5082),
#   ('서머너즈', 0.508),
#   ('소용', 0.5073),
#   ('기대감', 0.5068),
#   ('심정', 0.5064),
#   ('만화', 0.5059),
#   ('연동', 0.5052),
#   ('맵과', 0.5032),
#   ('반성', 0.5032),
#   ('실증', 0.5024),
#   ('기념', 0.5019),
#   ('회상', 0.5018),
#   ('황무지', 0.5012),
#   ('방안', 0.5012),
#   ('3쓰', 0.5011),
#   ('제작사', 0.501),
#   ('검은색', 0.5001),
#   ('모모', 0.4997),
#   ('센터', 0.4988),
#   ('혼자', 0.4967),
#   ('대부분', 0.4964),
#   ('테이트', 0.4956),
#   ('거짓말', 0.4954),
#   ('손길', 0.4952),
#   ('티키', 0.4949),
#   ('아침', 0.4948),
#   ('삼성', 0.4943),
#   ('희소', 0.4941),
#   ('가이드', 0.4931),
#   ('타이밍', 0.4928),
#   ('손맛', 0.4928),
#   ('무엇', 0.4909),
#   ('경악', 0.4909),
#   ('bts', 0.4908),
#   ('이런맵', 0.4907),
#   ('앱스토어', 0.4904),
#   ('최강', 0.489),
#   ('후자', 0.4885),
#   ('제미', 0.4879),
#   ('세련', 0.4871),
#   ('희열', 0.4862),
#   ('로제', 0.4858),
#   ('bgm', 0.4842),
#   ('차이', 0.4838),
#   ('골든타임', 0.4833),
#   ('새내기', 0.4832),
#   ('아웃', 0.4829),
#   ('유명', 0.4829),
#   ('온도', 0.4824),
#   ('화질', 0.4816),
#   ('초창', 0.4814),
#   ('특징', 0.4813),
#   ('가량', 0.4813),
#   ('말씀', 0.4813),
#   ('npc', 0.4797),
#   ('숙명', 0.4795),
#   ('스파더', 0.4783),
#   ('배르', 0.4782),
#   ('브금', 0.4781),
#   ('tty', 0.478),
#   ('접개', 0.4779),
#   ('피로', 0.4774),
#   ('여자', 0.4772),
#   ('55렙', 0.4771),
#   ('길이', 0.4761),
#   ('맘아', 0.4751),
#   ('개죧노잼', 0.475),
#   ('버팀목', 0.4746),
#   ('로비', 0.4736),
#   ('우르', 0.4727),
#   ('게시판', 0.4722),
#   ('템포', 0.4703),
#   ('모자', 0.4702),
#   ('활캐', 0.4693),
#   ('해결책', 0.4668),
#   ('안심', 0.4666),
#   ('여럽다', 0.4666),
#   ('우려', 0.4666),
#   ('타임', 0.4662),
#   ('통신', 0.4661),
#   ('드럼통', 0.4657),
#   ('상승', 0.4648),
#   ('소과금', 0.4641),
#   ('늪지대', 0.4626),
#   ('느낌표', 0.4622),
#   ('대채', 0.4618),
#   ('이벤', 0.4608),
#   ('스톱', 0.4605),
#   ('터치', 0.4601),
#   ('비율', 0.4591),
#   ('해상', 0.4589),
#   ('투자', 0.4582),
#   ('부위별코스튬', 0.4578),
#   ('점수', 0.4569),
#   ('접속자', 0.4567),
#   ('동작', 0.4565),
#   ('의심', 0.4561),
#   ('방패', 0.4556),
#   ('사기캐', 0.4553),
#   ('게속', 0.4551),
#   ('현재', 0.455),
#   ('동방', 0.4546),
#   ('수집', 0.4545),
#   ('근처', 0.4543),
#   ...],
#  [('유저', 121.53450000000002),
#   ('세븐나이츠', 65.82359999999998),
#   ('업데이트', 55.433000000000014),
#   ('생각', 54.78299999999998),
#   ('복귀', 53.925900000000006),
#   ('패치', 45.0404),
#   ('캐릭터', 43.220100000000016),
#   ('플레이', 40.10529999999997),
#   ('예전', 37.133),
#   ('지금', 33.5966),
#   ('정도', 32.4494),
#   ('이상', 32.445),
#   ('장비', 31.87870000000001),
#   ('리부트', 31.868699999999993),
#   ('대장간', 31.1063),
#   ('이번', 30.17599999999999),
#   ('영웅', 28.752399999999987),
#   ('시작', 27.754300000000008),
#   ('이벤트', 26.4846),
#   ('버그', 26.398699999999995),
#   ('각성', 24.927200000000003),
#   ('감사', 24.7222),
#   ('밸런스', 23.836399999999998),
#   ('시간', 23.5579),
#   ('때문', 23.149600000000007),
#   ('신화', 23.1043),
#   ('이후', 22.139),
#   ('보상', 22.042899999999992),
#   ('기존', 21.7877),
#   ('신규', 21.331500000000002),
#   ('스킬', 21.270499999999995),
#   ('안녕하세요', 21.0516),
#   ('처음', 20.8151),
#   ('동안', 20.7861),
#   ('사람', 20.176599999999993),
#   ('던전', 18.875599999999995),
#   ('오류', 18.7267),
#   ('필요', 18.079600000000003),
#   ('요즘', 17.2455),
#   ('부탁', 16.944599999999998),
#   ('오랜만', 16.9385),
#   ('컨텐츠', 16.6045),
#   ('결투', 16.515600000000003),
#   ('시스템', 16.372299999999996),
#   ('모험', 16.352400000000003),
#   ('문제', 16.082),
#   ('옛날', 15.7071),
#   ('접속', 15.4361),
#   ('이것', 15.432300000000005),
#   ('리뷰', 14.937099999999997),
#   ('난이도', 14.6843),
#   ('수정', 14.081100000000001),
#   ('신캐', 13.9097),
#   ('재미', 13.741300000000003),
#   ('강화', 13.678200000000002),
# ...
#   ('화면', 7.9819),
#   ('추천', 7.3697),
#   ('아이템', 7.189299999999999),
#   ('자유도', 7.1358),
#   ('플레이', 6.951),
#   ('고정', 6.543200000000001),
#   ('오랜만', 6.1426),
#   ('장비', 5.986900000000001),
#   ('진행', 5.931),
#   ('접속', 5.8016000000000005),
#   ('스카이', 5.7302),
#   ('레벨', 5.6248000000000005),
#   ('pc', 5.6114000000000015),
#   ('리뷰', 5.3633),
#   ('자체', 5.281300000000001),
#   ('컨텐츠', 4.9082),
#   ('느낌', 4.876200000000001),
#   ('스킬', 4.7299),
#   ('현지', 4.643800000000001),
#   ('캐릭터', 4.6072),
#   ('수정', 4.4361999999999995),
#   ('스토리', 4.3791),
#   ('조금', 4.290100000000001),
#   ('종료', 4.1576),
#   ('처음', 4.1318),
#   ('버튼', 4.114699999999999),
#   ('보상', 4.0853),
#   ('시리즈', 4.0602),
#   ('실망', 4.0082),
#   ('기능', 3.904),
#   ('하루', 3.8892),
#   ('모드', 3.8320000000000003),
#   ('이것', 3.7726999999999995),
#   ('전투', 3.7295000000000003),
#   ('사람', 3.4522),
#   ('유저', 3.4439),
#   ('오크', 3.3861),
#   ('카카오', 3.3509),
#   ('나름', 3.3288),
#   ('평점', 3.288),
#   ('자유', 3.2451999999999996),
#   ('종족', 3.2413),
#   ('만족', 3.2389),
#   ('중간', 3.2091000000000003),
#   ('터치', 3.1734),
#   ('원작', 3.1684000000000005),
#   ('현상', 3.0202999999999998),
#   ('무한', 2.8378),
#   ('완전', 2.8029),
#   ('로딩', 2.801),
#   ('노가다', 2.7654),
#   ('완료', 2.7628000000000004),
#   ('어디', 2.7423),
#   ('장신구', 2.7031),
#   ('발견', 2.676),
#   ('반복', 2.5987999999999998),
#   ('이벤트', 2.5794),
#   ('설치', 2.5603),
#   ('문제', 2.4923),
#   ('심연', 2.4686),
#   ('엘더', 2.4196),
#   ('짜증', 2.3967),
#   ('특정', 2.3882000000000003),
#   ('다운', 2.3786),
#   ('최고', 2.3745000000000003),
#   ('한글', 2.3727),
#   ('방식', 2.3629000000000002),
#   ('가능', 2.3531),
#   ('양산', 2.352),
#   ('공격', 2.3254),
#   ('정보', 2.3192),
#   ('핸드폰', 2.2974),
#   ('이름', 2.2917),
#   ('취향', 2.2885999999999997),
#   ('건물', 2.2635),
#   ('자동', 2.2497000000000003),
#   ('기분', 2.2481),
#   ('물약', 2.2211),
#   ('아무것', 2.2136),
#   ('전환', 2.197),
#   ('한국', 2.1691000000000003),
#   ('퀄리티', 2.1677),
#   ('존재', 2.167),
#   ('ip', 2.1535),
#   ('컨트롤', 2.1064),
#   ('요즘', 2.098),
#   ('오픈', 2.0703),
#   ('자신', 2.0683),
#   ('출시', 2.0463),
#   ('작업', 2.0294),
#   ('이후', 2.0228),
#   ('순간', 2.0140000000000002),
#   ('수준', 2.0116),
#   ('초반', 2.0025999999999997),
#   ('강제', 1.97),
#   ('소리', 1.9233),
#   ('프레임', 1.9162),
#   ('회전', 1.9151000000000002),
#   ('은근', 1.9099),
#   ('삭제', 1.893),
#   ('폰겜', 1.8825000000000003),
#   ('주작', 1.8501),
#   ('시스템', 1.8460999999999999),
#   ('먹통', 1.8106),
#   ('보스', 1.8067000000000002),
#   ('해골', 1.7955999999999999),
#   ('다양', 1.7725),
#   ('효과', 1.7711999999999999),
#   ('재료', 1.7207),
#   ('업뎃', 1.688),
#   ('길드', 1.6862),
#   ('거지', 1.6836),
#   ('개꿀잼', 1.6766999999999999),
#   ('상자', 1.6753),
#   ('신경', 1.6568),
#   ('장점', 1.6387),
#   ('선택', 1.633),
#   ('디테일', 1.6223999999999998),
#   ('지원', 1.5994000000000002),
#   ('여러분', 1.5896),
#   ('필요', 1.5719999999999998),
#   ('종일', 1.5548000000000002),
#   ('요소', 1.5525),
#   ('명성', 1.5393000000000001),
#   ('인터페이스', 1.5006),
#   ('최적', 1.4969000000000001),
#   ('법왕', 1.4889999999999999),
#   ('확인', 1.4581),
#   ('조절', 1.453),
#   ('배터리', 1.4502),
#   ('별점', 1.4444000000000001),
#   ('진짜', 1.408),
#   ('버전', 1.4009),
#   ('노트', 1.3857),
#   ('분해', 1.3718),
#   ('불가', 1.3548),
#   ('먹칠', 1.3519),
#   ('렉이', 1.3504),
#   ('전체', 1.3474),
#   ('패키지', 1.331),
#   ('힘듬', 1.3096),
#   ('최적화', 1.3047),
#   ('네트워크', 1.2993000000000001),
#   ('안정', 1.2876000000000003),
#   ('망겜', 1.2869000000000002),
#   ('파밍', 1.2772000000000001),
#   ('어플', 1.2731),
#   ('최대', 1.2673),
#   ('내용', 1.2634),
#   ('경우', 1.2629000000000001),
#   ('아레나', 1.2609),
#   ('세계관', 1.2578),
#   ('목걸이', 1.2561),
#   ('과금', 1.2547),
#   ('크롤', 1.2487),
#   ('고퀄', 1.2461),
#   ('서버', 1.234),
#   ('암살', 1.2256),
#   ('한계', 1.2252999999999998),
#   ('진심', 1.2234),
#   ('유도', 1.2169),
#   ('갓겜', 1.2062),
#   ('개인', 1.1963),
#   ('잠입', 1.1962),
#   ('고블린', 1.1926),
#   ('장착', 1.1892999999999998),
#   ('월드', 1.1688),
#   ('여기', 1.1665999999999999),
#   ('드랍', 1.1623),
#   ('거미', 1.1567),
#   ('상점', 1.1564999999999999),
#   ('잠금', 1.131),
#   ('이번', 1.1268),
#   ('분위기', 1.1135000000000002),
#   ('기고', 1.0995),
#   ('발생', 1.0947),
#   ('정신', 1.0899),
#   ('그것', 1.0897000000000001),
#   ('관리', 1.0745),
#   ('포인트', 1.073),
#   ('감안', 1.0706),
#   ('에보니', 1.0688),
#   ('업데이트', 1.0613000000000001),
#   ('베데스다', 1.0599),
#   ('여왕', 1.0599),
#   ('진입', 1.0534),
#   ('몰입', 1.0441),
#   ('죽음', 1.0369),
#   ('감성', 1.0315),
#   ('상품', 1.0272),
#   ('건축', 1.0252999999999999),
#   ('알바', 1.0245),
#   ('명작', 1.0186000000000002),
#   ('제한', 1.0143),
#   ('최악', 1.0021),
#   ('동안', 1.0018),
#   ('메인퀘', 1.0008),
#   ('놀람', 1.0),
#   ('감동', 1.0),
#   ('한동안', 1.0),
#   ('재밋고', 1.0),
#   ('중후반', 1.0),
#   ('최애게', 1.0),
#   ('보람', 1.0),
#   ('유혹', 1.0),
#   ('성취감', 1.0),
#   ('노잼', 1.0),
#   ('핵폭탄', 1.0),
#   ('인간', 1.0),
#   ('모륵게', 1.0),
#   ('쓰레기', 1.0),
#   ('굿굿귯', 1.0),
#   ('쏘쏘', 1.0),
#   ('푸스로', 1.0),
#   ('애메', 1.0),
#   ('good', 1.0),
#   ('예전', 0.9998),
#   ('추억', 0.9952),
#   ('생성', 0.9890999999999999),
#   ('구현', 0.9884),
#   ('팅겨요', 0.9854),
#   ('엘더스크롤을모바일로가지고았다해도', 0.9846),
#   ('무기', 0.9839),
#   ('두꺼비', 0.9787),
#   ('사냥', 0.9786),
#   ('환불', 0.9779),
#   ('설정', 0.9772000000000001),
#   ('건설', 0.9748),
#   ('부탁', 0.9682),
#   ('렙제있어', 0.9669),
#   ('빼애애태앹애애애앵', 0.9648),
#   ('애미야', 0.9578),
#   ('외국', 0.9556),
#   ('만큼', 0.9495),
#   ('타격감', 0.9479),
#   ('원래', 0.9478),
#   ('시점', 0.9429000000000001),
#   ('구매', 0.9422),
#   ('안데죠오오오오', 0.9393),
#   ('겜삭제', 0.9386),
#   ('팅기지나', 0.9355),
#   ('방법', 0.9293),
#   ('구간', 0.9288),
#   ('움직임', 0.9277),
#   ('추가', 0.9267),
#   ('캐릭커스텀마이징', 0.9265),
#   ('킬링타임', 0.9235),
#   ('완벽', 0.9229),
#   ('안주', 0.9208),
#   ('몰입도', 0.9194),
#   ('드래곤', 0.9181),
#   ('동일', 0.9163),
#   ('모험', 0.912),
#   ('섭취', 0.9109),
#   ('왤케', 0.9107),
#   ('연마', 0.9046000000000001),
#   ('걱정', 0.9023),
#   ('rpg', 0.8983),
#   ('응옹', 0.8956),
#   ('켜도', 0.8947),
#   ('전설', 0.8895),
#   ('제니어맥스', 0.8823),
#   ('주퀘스트', 0.881),
#   ('캐릭', 0.8803),
#   ('설명', 0.8799),
#   ('빡시', 0.8768),
#   ('장벽', 0.8762),
#   ('께임', 0.8709),
#   ('베타테스터', 0.8695),
#   ('즐겜', 0.8627),
#   ('따위', 0.8624),
#   ('이유', 0.8619),
#   ('퍼블리셔', 0.8593),
#   ('그거', 0.8587),
#   ('안대', 0.8544),
#   ('애애앵', 0.8517),
#   ('스타일', 0.8507),
#   ('해결', 0.8457),
#   ('최신', 0.8431),
#   ('제어', 0.8422),
#   ('무시', 0.8389),
#   ('중국어', 0.8346),
#   ('클래식', 0.8341),
#   ('감사', 0.8325),
#   ('갑옷', 0.8308),
#   ('껏다켜', 0.8295),
#   ('재밋네요', 0.8289),
#   ('문의', 0.8286),
#   ('이하', 0.8273),
#   ('사용', 0.8259000000000001),
#   ('대결', 0.8249),
#   ('짜임새', 0.8247),
#   ('초딩', 0.8193),
#   ('특유', 0.8192999999999999),
#   ('때문', 0.8178000000000001),
#   ('바퀴', 0.8162),
#   ('상태', 0.8134),
#   ('타이틀', 0.8113),
#   ('가로세로', 0.8092),
#   ('메인퀘다', 0.8082),
#   ('퍼즐', 0.8047),
#   ('번역기', 0.8034),
#   ('수업', 0.8011),
#   ('소모', 0.7975),
#   ('잼쓰요', 0.7954),
#   ('방향', 0.7939),
#   ('케릭', 0.7925),
#   ('대머리', 0.7922),
#   ('프스', 0.7914),
#   ('일전', 0.7874),
#   ('다운로드', 0.7848),
#   ('옛날', 0.7838),
#   ('개선', 0.7778),
#   ('단순', 0.7759),
#   ('토트', 0.7724),
#   ('집중도', 0.7709),
#   ('퇴근', 0.7694),
#   ('무엇', 0.7646),
#   ('그전', 0.7634),
#   ('볼륨', 0.763),
#   ('스스로', 0.7618),
#   ('엘더6', 0.7614),
#   ('번역퀄', 0.7605),
#   ('dd', 0.7603),
#   ('나이스', 0.7594),
#   ('얼굴', 0.756),
#   ('잡거', 0.7557),
#   ('현질아템이', 0.7553),
#   ('만띵', 0.7553),
#   ('푸스', 0.7527),
#   ('프로그래머', 0.7522),
#   ('조이스틱', 0.7494),
#   ('메인', 0.7476),
#   ('제격', 0.7457),
#   ('똥망겜', 0.7442),
#   ('사이', 0.7365999999999999),
#   ('스펠', 0.735),
#   ('취소', 0.7348),
#   ('우기', 0.7322),
#   ('메일', 0.7319),
#   ('영화', 0.7294),
#   ('엔피', 0.7284),
#   ('맵이', 0.7263),
#   ('건축물', 0.7243),
#   ('첫사랑', 0.7226),
#   ('korea', 0.716),
#   ('환경', 0.7141),
#   ('치욕', 0.7138),
#   ('실상', 0.7114),
#   ('온라인', 0.7096),
#   ('친구', 0.7093),
#   ('대존잼', 0.7081),
#   ('베데스타', 0.7073),
#   ('퀘다깸', 0.7062),
#   ('패턴', 0.7061999999999999),
#   ('폭망겜', 0.7056),
#   ('카카', 0.7054),
#   ('트리', 0.7046),
#   ('수령', 0.7046),
#   ('제미', 0.6999),
#   ('표현', 0.6976),
#   ('패치', 0.6975),
#   ('반신반의', 0.697),
#   ('강요', 0.6963),
#   ('ui', 0.6959),
#   ('업체', 0.6939),
#   ('적정', 0.6935),
#   ('조건', 0.6934),
#   ('개구리', 0.6925),
#   ('맵과', 0.6896),
#   ('영어닉', 0.6896),
#   ('개노잼', 0.6801),
#   ('특옵', 0.6795),
#   ('중국', 0.6783),
#   ('채팅', 0.6777),
#   ('스타터', 0.6774),
#   ('인정', 0.6739),
#   ('아이패드', 0.6737),
#   ('어디죠', 0.6719),
#   ('핵노잼', 0.6716),
#   ('팅기고', 0.6694),
#   ('홍보', 0.6654),
#   ('박자', 0.663),
#   ('활로', 0.6626),
#   ('언어', 0.6588),
#   ('몬스터', 0.6585),
#   ('스토리텔링', 0.6576),
#   ('번째', 0.6552),
#   ('가챠', 0.6548),
#   ('로드', 0.6517),
#   ('필요량', 0.6504),
#   ('표시', 0.6499),
#   ('결혼', 0.6468),
#   ('제보', 0.6427),
#   ('계속', 0.6408),
#   ('거세', 0.6408),
#   ('결제', 0.6398),
#   ('휴대폰', 0.638),
#   ('충족', 0.6342),
#   ('대장간', 0.6337),
#   ('인생', 0.6337),
#   ('근황', 0.6335),
#   ('레드', 0.6302),
#   ('리치', 0.6279),
#   ('가성비', 0.6277),
#   ('작동', 0.6276),
#   ('블레이드', 0.6274),
#   ('반나절', 0.6256),
#   ('입장', 0.6236),
#   ('반환', 0.6226),
#   ('뎀지', 0.6225),
#   ('외형', 0.6217),
#   ('모션', 0.6209),
#   ('vpn', 0.6208),
#   ('직업', 0.6203),
#   ('조정', 0.6194),
#   ('권장렙7', 0.6181),
#   ('물결표', 0.6167),
#   ('보스몹', 0.6158),
#   ('입구', 0.6132),
#   ('국산', 0.6117),
#   ('일반', 0.6113),
#   ('허접', 0.6105),
#   ('동시', 0.61),
#   ('판매', 0.6092),
#   ('레어', 0.6087),
#   ('리니지', 0.6067),
#   ('아쉬움', 0.6051),
#   ('여타', 0.602),
#   ('천지', 0.6007),
#   ('반지', 0.6003),
#   ('하드', 0.5953),
#   ('컴퓨터', 0.5949),
#   ('조치', 0.5924),
#   ('돋보기', 0.5918),
#   ('삼성', 0.5911),
#   ('해외판', 0.5911),
#   ('현실', 0.5888),
#   ('등등', 0.5865),
#   ('특성', 0.585),
#   ('사상', 0.5842),
#   ('드워븐', 0.5834),
#   ('강화', 0.5825),
#   ('느낌표', 0.5797),
#   ('육성', 0.5795),
#   ('플래쉬', 0.5791),
#   ('종류', 0.5784),
#   ('비트', 0.5783),
#   ('사양', 0.5772),
#   ('메시지', 0.5765),
#   ('정신병', 0.5761),
#   ('스트레스', 0.5744),
#   ('때매', 0.5714),
#   ('커뮤', 0.569),
#   ('발표', 0.5676),
#   ('기회', 0.567),
#   ('구입', 0.5641),
#   ('예약', 0.5641),
#   ('반말', 0.5635),
#   ('달성', 0.5617),
#   ('급상승', 0.5613),
#   ('로그인', 0.5605),
#   ('나라', 0.5581),
#   ('옵션', 0.5569),
#   ('딱지', 0.5568),
#   ('최저', 0.5553),
#   ('내포', 0.5542),
#   ('만점', 0.5533),
#   ('가입', 0.5518),
#   ('당연', 0.5516),
#   ('친절', 0.5514),
#   ('상황', 0.55),
#   ('검색어', 0.5497),
#   ('유형시스탬이있았으며뉴할만할거같을겁니다', 0.5496),
#   ('개성', 0.5489),
#   ('카톡', 0.5478),
#   ('클릭', 0.547),
#   ('브라스', 0.5461),
#   ('배틀', 0.5456),
#   ('퍼센트', 0.5449),
#   ('시기', 0.5426),
#   ('왈도체', 0.5402),
#   ('다음', 0.5393),
#   ('스킨', 0.5392),
#   ('뉴베', 0.5381),
#   ('애당초', 0.5379),
#   ('위주', 0.5377),
#   ('주변', 0.5372),
#   ('경고', 0.5369),
#   ('설상가상', 0.5362),
#   ('토리', 0.5355),
#   ('경비병', 0.5343),
#   ('임프똥', 0.5337),
#   ('기준', 0.5336),
#   ('스림', 0.5329),
#   ('영어', 0.5283),
#   ('엉망진창', 0.5276),
#   ('실정', 0.5256),
#   ('오브젝트', 0.5253),
#   ('먹이', 0.5253),
#   ('렙업', 0.5247),
#   ('콘텐츠', 0.5236),
#   ('충전', 0.523),
#   ('거기', 0.5228),
#   ('선택지', 0.5226),
#   ('개연', 0.5225),
#   ('시판', 0.52),
#   ('가차', 0.5195),
#   ('센터', 0.5191),
#   ('안녕하세요', 0.5187),
#   ('아시아', 0.5184),
#   ('캐쉬', 0.5176),
#   ('절반', 0.5137),
#   ('필드', 0.5132),
#   ('회정', 0.5116),
#   ('계획', 0.5112),
#   ('치명', 0.511),
#   ('전후', 0.5109),
#   ('캐릭도구려', 0.5108),
#   ('덩어리', 0.5096),
#   ('shop', 0.5061),
#   ('투자', 0.5052),
#   ('약간', 0.5041),
#   ('문구', 0.5039),
#   ('대화', 0.5027),
#   ('인식', 0.5014),
#   ('게이지', 0.5011),
#   ('수록', 0.5008),
#   ('인벤', 0.5007),
#   ('9랩', 0.5004),
#   ('사용자', 0.5003),
#   ('쿼스트', 0.4984),
#   ('존댓말', 0.4982),
#   ('므슨뜻', 0.4971),
#   ('위험', 0.4957),
#   ('근대', 0.4948),
#   ('불평', 0.4944),
#   ('중학교', 0.4935),
#   ('투구', 0.4923),
#   ('엉망', 0.4911),
#   ('한마디', 0.4905),
#   ('적용', 0.4903),
#   ('단조', 0.4869),
#   ('모니터', 0.4868),
#   ('모집', 0.4863),
#   ('결론', 0.484),
#   ('일본어', 0.4839),
#   ('리엘', 0.4835),
#   ('택지', 0.4818),
#   ('정확', 0.4815),
#   ('음식', 0.4804),
#   ('고집', 0.4803),
#   ('여야', 0.4797),
#   ('강조', 0.4796),
#   ('나오르', 0.4793),
#   ('권장', 0.4777),
#   ('써잇엇우', 0.4776),
#   ('퀘스크', 0.4773),
#   ('피로', 0.4763),
#   ('emails', 0.4753),
#   ('전투력', 0.4749),
#   ('본사', 0.4725),
#   ('덕분', 0.4723),
#   ('몇일', 0.4714),
#   ('마찬가지', 0.4712),
#   ('편의', 0.4704),
#   ('유료', 0.4703),
#   ('에디션', 0.4683),
#   ('마크', 0.4682),
#   ('수리', 0.4677),
#   ('반응', 0.4672),
#   ('마음', 0.4666),
#   ('기존', 0.4665),
#   ('템업', 0.4663),
#   ('상정', 0.4661),
#   ('문제점', 0.4645),
#   ('노트8', 0.4645),
#   ('춰러', 0.4643),
#   ('취향저격', 0.4623),
#   ('잡화점', 0.4621),
#   ('개발', 0.4602),
#   ('나중', 0.4597),
#   ('실크', 0.4574),
#   ('주위', 0.4563),
#   ('마무리', 0.4518),
#   ('단계', 0.4518),
#   ('소용', 0.4516),
#   ('해제', 0.451),
#   ('정상', 0.4503),
#   ('미흡', 0.45),
#   ('최선', 0.4497),
#   ('서점', 0.4483),
#   ('오토', 0.4477),
#   ('회사', 0.4474),
#   ('증세', 0.4468),
#   ('선물', 0.4456),
#   ('미니맵', 0.4454),
#   ('투기장', 0.4451),
#   ('호구', 0.4448),
#   ('장검', 0.4444),
#   ('등급', 0.4442),
#   ('도전', 0.4385),
#   ('이해도', 0.4381),
#   ('알아줫우', 0.4371),
#   ('보안', 0.4367),
#   ('부분', 0.4362),
#   ('한국어', 0.4358),
#   ('기술', 0.4352),
#   ('오블리비언', 0.4334),
#   ('각종', 0.4332),
#   ('보유하규', 0.4326),
#   ('작품', 0.4319),
#   ('무료', 0.4311),
#   ('컨투', 0.4301),
#   ('세트', 0.43),
#   ('므슨', 0.4297),
#   ('하급', 0.4292),
#   ('일정', 0.4282),
#   ('복구', 0.428),
#   ('방어', 0.4276),
#   ('초월', 0.4273),
#   ('순수', 0.4258),
#   ('무과금', 0.4255),
#   ('단점', 0.425),
#   ('둘째', 0.4247),
#   ('보름', 0.4233),
#   ('장난', 0.4224),
#   ('여관', 0.4223),
#   ('완성', 0.4217),
#   ('하락', 0.4213),
#   ('지금', 0.4209),
#   ('사전', 0.4197),
#   ('가지', 0.4194),
#   ('상승', 0.419),
#   ('신기', 0.4188),
#   ('구글', 0.4185),
#   ('깔끔', 0.4184),
#   ('새벽', 0.4181),
#   ('임무', 0.4177),
#   ('조각', 0.4175),
#   ('노답', 0.417),
#   ('고객', 0.4168),
#   ('2렙', 0.4155),
#   ('방기', 0.4154),
#   ('번거럽고', 0.414),
#   ('극대', 0.4138),
#   ('dex', 0.4136),
#   ('연결', 0.4091),
#   ('저녁', 0.409),
#   ('off', 0.4085),
#   ('현재', 0.4081),
#   ('효율', 0.4073),
#   ('정식', 0.4041),
#   ('간판', 0.4028),
#   ('잡템', 0.4026),
#   ('개념', 0.4018),
#   ('방도', 0.4017),
#   ('주택', 0.4016),
#   ('퍼크', 0.4015),
#   ('먹물', 0.4014),
#   ('대변', 0.4013),
#   ('on', 0.4003),
#   ('수작', 0.3999),
#   ('단검', 0.398),
#   ('액션', 0.3979),
#   ('콘솔', 0.3976),
#   ('가판대', 0.397),
#   ('머리', 0.3958),
#   ('시말서', 0.3956),
#   ('눈치', 0.3939),
#   ('ps', 0.3935),
#   ('지옥', 0.3932),
#   ('보너스', 0.3926),
#   ('초록색', 0.3917),
#   ('스틸', 0.3911),
#   ('선형', 0.3907),
#   ('우려', 0.3905),
#   ('서브', 0.3899),
#   ('sigil', 0.3896),
#   ('도중', 0.389),
#   ('스크롤', 0.3867),
#   ('기획', 0.3862),
#   ('버벅거', 0.386),
#   ('전작', 0.3838),
#   ('메뉴', 0.3823),
#   ('보기', 0.382),
#   ('생명', 0.3784),
#   ('치명타', 0.377),
#   ('인체', 0.3761),
#   ('비용', 0.3757),
#   ('차별', 0.3754),
#   ('강력', 0.3735),
#   ('scrolls', 0.3714),
#   ('제작', 0.3709),
#   ('일인칭', 0.3701),
#   ('무과', 0.3701),
#   ('이동', 0.3689),
#   ('개판', 0.3688),
#   ('perks', 0.3688),
#   ('매크로', 0.3678),
#   ('울티마', 0.3678),
#   ('패키', 0.3671),
#   ('게임패드', 0.3667),
#   ('적응', 0.3647),
#   ('오작동', 0.3641),
#   ('나머지', 0.362),
#   ('커버', 0.36),
#   ('차이점', 0.3593),
#   ('작용', 0.3584),
#   ('생명력', 0.358),
#   ('해체', 0.3558),
#   ('반영', 0.3552),
#   ('유명', 0.3534),
#   ('북미', 0.3533),
#   ('저장', 0.3508),
#   ('욕심', 0.3502),
#   ('경험', 0.3497),
#   ('충돌', 0.3485),
#   ('비교', 0.3423),
#   ('communication', 0.3415),
#   ('포획', 0.3407),
#   ('어엌', 0.3403),
#   ('짝퉁', 0.3401),
#   ('대장', 0.3391),
#   ('도입', 0.3387),
#   ('사자', 0.3384),
#   ('허가', 0.3372),
#   ('상대', 0.3358),
#   ('은신', 0.3345),
#   ('마지막', 0.3325),
#   ('악순환', 0.3319),
#   ('서양', 0.331),
#   ('점검', 0.33),
#   ('직업군', 0.3288),
#   ('발품', 0.3287),
#   ('극한', 0.328),
#   ('쉘터', 0.3278),
#   ('탐험', 0.3271),
#   ('unavailable', 0.327),
#   ('online', 0.325),
#   ('주간', 0.3243),
#   ('사물', 0.3229),
#   ('얼마', 0.3201),
#   ('타입', 0.3186),
#   ('기사단', 0.3176),
#   ('팩트', 0.3166),
#   ('갈증', 0.3164),
#   ('언제', 0.3122),
#   ('error', 0.3107),
#   ('상호', 0.3095),
#   ('구조', 0.3089),
#   ('싸움', 0.3087),
#   ('업그레이드', 0.3083),
#   ('튜토리얼', 0.3072),
#   ('잔렉이', 0.3066),
#   ('포기', 0.3058),
#   ('있엇습', 0.3058),
#   ('치중', 0.299),
#   ('화살공걱이나', 0.2928),
#   ('부족', 0.2914),
#   ('애초', 0.2866),
#   ('최소한', 0.2827),
#   ('골수', 0.2812),
#   ('채집', 0.2805),
#   ('translation', 0.2749),
#   ('실행', 0.2746),
#   ('괴랄', 0.2742),
#   ('파괴', 0.2738),
#   ('publicing', 0.2737),
#   ('레전드', 0.2719),
#   ('log', 0.2699),
#   ('쌍수', 0.2697),
#   ('공략', 0.2687),
#   ('본섭', 0.2677),
#   ('농장', 0.2676),
#   ('형식', 0.2644),
#   ('길이', 0.2638),
#   ('머리채', 0.2632),
#   ('팔방', 0.2622),
#   ('elder', 0.2615),
#   ('이용', 0.261),
#   ('유발', 0.2605),
#   ('메이지', 0.2603),
#   ('완성도', 0.2566),
#   ('발열', 0.2543),
#   ('원거리', 0.2471),
#   ('client', 0.2465),
#   ('베타', 0.2452),
#   ('인칭', 0.2438),
#   ('하자', 0.2418),
#   ('언급', 0.2392),
#   ('수리비', 0.2355),
#   ('kr', 0.226),
#   ('영문', 0.2258),
#   ('폴아웃', 0.2204),
#   ('초기', 0.2201),
#   ('수급', 0.2195),
#   ('작성자', 0.2194),
#   ('당장', 0.2162),
#   ('의심', 0.2055),
#   ('퍼블리싱', 0.2032),
#   ('it', 0.1943),
#   ('최근', 0.1907),
#   ('덱스', 0.1806),
#   ('lease', 0.1733),
#   ('shut', 0.1704),
#   ('is', 0.1638),
#   ('연동', 0.1601),
#   ('the', 0.1484),
#   ('국내', 0.1454),
#   ('인치', 0.1355),
#   ('모양', 0.1301),
#   ('마우', 0.124),
#   ('their', 0.1212),
#   ('help', 0.1045),
#   ('them', 0.1002),
#   ('couldn', 0.0785),
#   ('ten', 0.0646),
#   ('are', 0.0543),
#   ('we', 0.0351),
#   ('in', 0.0278),
#   ('and', 0.022),
#   ('all', 0.0206),
#   ('so', 0.0178),
#   ('happens', 0.0133),
#   ('ask', 0.0051),
#   ('day', 0.005),
#   ('can', -0.0182)]]

# %%
d_idf = defaultdict(int)

for game_keywords in li:
    for key, _ in game_keywords:
        d_idf[key] += 1

# %%
tf_idf = []

N = len(li)

for i in range(len(li)):
    n_tuple = []
    for j in range(len(li[i])):
        n_tuple.append([li[i][j][0], li[i][j][1] * math.log(N / d_idf[li[i][j][0]] + 1)])
        
    n_tuple.sort(key= lambda x : -x[1])
    only_keywords = []
    for key in n_tuple[:10]:
        only_keywords.append(key[0])
    tf_idf.append(only_keywords)

# %%
print(tf_idf)
# Out:
# [['선수', '축구', '재미', '감독', 'fm', '시간', '재밋네', '나름', '영입', '전술'], ['행템', '모마', '마블', '주사위', '유저', '아이템', '캐릭터', '행운', '카드', '확률'], ['신장', '유저', '업데이트', '대륙', '몬스터', '캐릭터', '복귀', '옛날', '초월', '미나'], ['세븐나이츠', '리부트', '대장간', '유저', '신화', '복귀', '각성', '영웅', '업데이트', '생각'], ['오락실', '추억', '베이비', '파이터', '재미', '옛날', '실행', '오랜만', '스트레스', '컴온'], ['장수', '삼국지', '디펜스', '나팔', '루비', '군웅', '마음의소리', '도감', '소탕', '업데이트'], ['히어로', '헬히', '영정', '캐럿', '유저', '헬로', '접속', '영웅', '정지', '영구'], ['히어로', '헬로', '재미', '영웅', '폭군', '캐릭터', '시간', '그래픽', '모험', '킬링타임'], ['자질', '격투', '접속', '업데이트', '대전', '킹오파', '서버', '다이아', '현지', '유저'], ['통신', '하트', '상태', '에브리타운', '접속', '재미', '퍼즐', '캐릭터', '시간', '종료'], ['영웅', '초코', '업데이트', '화면', '환생', '바하무트', '실행', '접속', '복귀', '주년'], ['낚시', '물고기', '바다', '어부', '수족관', '라이벌', '피싱', '손맛', '접속', '장비'], ['유저', '퍼스트', '별되', '업데이트', '복귀', '퍼임', '인피니티', '신위', '동료', '캐릭터'], ['광고', '럭키', '업데이트', '레스토랑', '식당', '음식', '요리', '마리셰', '음식점', '다이아'], ['시간', '캔디팡', '하트', '업데이트', '재미', '챔피언스리그', '리그', '중독', '스테이지', '아이템'], ['올인', '상대방', '보너스', '상대', '뒷패', '오링', '조작', '사람', '스트레스', '현지'], ['리니지', '아키에이지', '오딘', '그래픽', '사냥', '작업장', '리니지2', '퀘스트', '접속', '탈것'], ['슈트', '발열', '그래픽', 'sf', 'pc', '재미', '아레스', '타격감', '리니지', '필드'], ['영지', '에버', '스토리', '소울', '캐릭터', '정령', '버그', '컨텐츠', '플레이', '모델링'], ['팝콘', '프렌즈', '광고', '아이템', '하트', '레벨', '업데이트', '오류', '신비', '이벤트'], ['오류', '하트', '사천성', '인터넷', '접속', '시간', '광고', '아이템', '화면', '짜증'], ['하트', '홀리데이', '난이도', '프렌즈', '스테이지', '타워', '아이템', '연회', 'vip', '업데이트'], ['타운', '프렌즈', '퍼즐', '스테이지', '하트', '난이도', '큐브', '아이템', '블럭', '클리어'], ['스토리', '가테', '패러디', '가디언', '도트', '캐릭터', '퍼즐', '테일즈', '플레이', '컨텐츠'], ['그랜드체이스', '그체', '캐릭터', 'ss', '체이서', '유저', '업데이트', '플레이', '스토리', '생각'], ['bt', '아미', '캐릭터', '츄러스', '이모티콘', '방탄', '스토리', '난이도', '퍼즐', '스테이지'], ['업데이트', '여명', '정리', '갱신', '네트워크', '다운', '다운로드', '와이파이', '시간', '카카오페이지'], ['달빛조각사', '버그', '퀘스트', '사냥', '원작', '소설', '거래소', '플레이', '유저', '몬스터'], ['공방', '마이', '업데이트', '퀘스트', '창고', '플레이', '의뢰', '유저', '시장', '협회'], ['아이러브니키', '니키', '의상', '이벤트', '루비', '도안', '오디션', '한복', '여정', '유저'], ['오딘', '그래픽', '접속', '리니지', '유저', '과금', '강화', '정도', '사냥', '대기'], ['애니메이션', '쥬얼', '가챠', '캐릭터', '스토리', '보이스', '프리코', '정도', '플레이', '협동'], ['우마무스메', '육성', '운영', '경마', '가챠', '챔미', '미팅', '일본', '정도', '쥬얼'], ['핀볼', '도트', '스토리', '캐릭터', '가챠', '컨텐츠', '재미', '플레이', '일본', '운영'], ['초코', '접속', '업데이트', '점핑', '탈퇴', 'agreement', '로그인', '메밀', '쵸코', '오류'], ['태연', '마법', '캐릭터', '검마', '그래픽', '업데이트', 'ost', '점핑', 'pk', '시작'], ['열혈강호', '금화', '열강', '그래픽', '캐릭터', '케릭', '유저', '컨트롤', '플레이', '카카오페이지'], ['디즈니', '펜스', '하트', '그림', '시즌', '시간', '인어공주', '업데이트', '아이', '재미'], ['올인', '한방', '뗴우기', '따블', '연승', '장보기', '코스튬', '재미', '시간', '상대방'], ['농장', '숲속', '크루톤', '도끼', '접속', '과일나무', '나무', '확장', '창고', '블루젬'], ['바둑', '계가', '대국', '형세', '초읽기', '급수', '타이젬', '접속', '관전', '기력'], ['광고', '대국', '장기', '기물', '접속', '시간', '상대방', '짜증', '업데이트', '고의'], ['대국', '상대방', '광고', '시간', '착수', '접속', '기권', '렌주', '급수', '매너'], ['올인', '상대방', '보너스', '피망', '업데이트', '오링', '뒷패', '조작', '몰아주기', '랜덤'], ['포커', '업데이트', '피망', '시간', '오링', '머니', '올인', '짱구', '배팅', '재미'], ['광땡', '시간', '재미', '장땡', '피망', '올인', '섯다', '스릴', '피망섯다', '오링'], ['업데이트', '하트', '시간', '대전', '사천성', '오류', '스테이지', '아이템', '네트워크', '블럭'], ['유저', '나라', '도안', '버그', '사냥', '슈퍼캣', '레이드', '생각', '확률', '아이템'], ['히트', '리니지', '히트1', '오딘', '히트2', '그래픽', '넥슨', '리니지2', '유저', '과금'], ['카트', '라이더', '건전지', '카러플', '드리프트', '유저', '랭킹', '라이선스', '트랙', '플레이'], ['메이플', '메소', '메이플스토리', '포스', 'pc', '유저', '사냥', '플레이', '퀘스트', '컴메'], ['그래픽', '넥슨', '강화', '사냥', '유저', '필드', '퀘스트', '플레이', '자동', '생각'], ['진주', '바이킹', '바아', '업데이트', '건물', '접속', '아일랜드', '업뎃', '흑진주', '유저'], ['포코팡', '포코포코', '시간', '포코', '업데이트', '체리', '동물', '재미', '챕터', '모험'], ['프렌즈', '업데이트', '광고', '플레이', '아이템', '크라운', '합성', '삭제', '시간', '짜증'], ['미용', '러브', '라이센스', '로딩', '미용실', '스타일', '오랜만', '헤어', '시작', '가구'], ['레시피', '딜리버리', '햄버거', '해피', '접속', '커피', '버거', '재미', '시작', '친구'], ['용병', '파견', '탐험', '여관', '버그', '러브', '시간', '일손', '가판대', '오류'], ['레시피', '콜렉션', '오류', '오랜만', '업데이트', '보상', '메일', '버그', '고양이', '수정'], ['크루', '마트', '주문서', '탐험', '품절' ...

# %%
df = pd.DataFrame(columns=['game_name','keywords'])
df['game_name'] = review_files
df['keywords'] = tf_idf
df
# Out:
#                           game_name  \
# 0            ./DF\AIGames.DSFMK.csv
# 1   ./DF\cjenm.ModooMarbleKakao.csv
# 2            ./DF\cjenm.monster.csv
# 3           ./DF\cjenm.sknights.csv
# 4    ./DF\Danalgames.CobFighter.csv
# ..                              ...
# 86   ./DF\SuperAwesome.HKFKakao.csv
# 87      ./DF\webzen.mua2.google.csv
# 88             ./DF\wemade.mir4.csv
# 89             ./DF\wemade.mirm.csv
# 90  ./DF\zenimax.bladeskakaonew.csv
#
#                                            keywords
# 0         [선수, 축구, 재미, 감독, fm, 시간, 재밋네, 나름, 영입, 전술]
# 1       [행템, 모마, 마블, 주사위, 유저, 아이템, 캐릭터, 행운, 카드, 확률]
# 2      [신장, 유저, 업데이트, 대륙, 몬스터, 캐릭터, 복귀, 옛날, 초월, 미나]
# 3   [세븐나이츠, 리부트, 대장간, 유저, 신화, 복귀, 각성, 영웅, 업데이트, 생각]
# 4    [오락실, 추억, 베이비, 파이터, 재미, 옛날, 실행, 오랜만, 스트레스, 컴온]
# ..                                              ...
# 86   [키티, 헬로키티, 쿠로미, 캐릭터, 산리오, 사과, 재미, 시간, 프렌즈, 친구]
# 87        [엔젤, 웹젠, 접속, 과금, 아크, 보스, 재미, 생각, 현지, 그래픽]
# 88   [미르4, 그래픽, 미르, 채집, 업데이트, 플레이, 접속, 컨텐츠, 토벌, 진행]
# 89       [미르, 그래픽, 리니지, 진행, 사냥, 재미, 화신, 버그, 과금, 유저]
# 90   [엘더스크롤, 번역, 가로, 세로, 스카이, 통신, 퀘스트, 오크, 자유도, 던전]
#
# [91 rows x 2 columns]

# %%
df.to_csv('game_keywords.csv', index=False)
